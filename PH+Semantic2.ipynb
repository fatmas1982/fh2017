# %%
import nltk
from collections import Counter
import pandas as pd

# %% [markdown]
# # Read File

# %%
new_path = '/home/cloudera/cs.txt'
def read_file(str):
    file = open(str,'r')
    txt=file.read()
    #print(txt)
    return txt

# %%
txt=read_file(new_path)

# %%
type(txt)
# Out:
# str

# %% [markdown]
# # Split text to pragraphs

# %%
def txt_pragraphs(str):
    pragraphs = str.split("\n\n")
    return pragraphs
pragraphs=txt_pragraphs(txt)
type(pragraphs)
# Out:
# list

# %%
pragraphs[1]
# Out:
# '\nComputer science is a discipline that spans theory and practice. It requires thinking both in abstract terms and in concrete terms. The practical side of computing can be seen everywhere. Nowadays, practically everyone is a computer user, and many people are even computer programmers.\nGetting computers to do what you want them to do requires intensive hands-on experience. But computer science can be seen on a higher level, as a science of problem solving. Computer scientists must be adept at modeling and analyzing problems. They must also be able to design solutions and verify that they are correct. Problem solving requires precision, creativity, and careful reasoning.'

# %% [markdown]
# # Split Pragraph to Sentences

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
#print(sent_tokenize(pragraphs(txt)[1]))
def pragraph_to_setnences(str):
    return sent_tokenize(str)
setnences=pragraph_to_setnences(pragraphs[1])

# %% [markdown]
# ## Word Process For Sentence

# %%
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer

# %% [markdown]
# ## Removing English stopwords and Punct per Sentence

# %%
new_stop_words = ['the', 'that', 'to', 'as', 'there', 'has', 'and', 'or', 'is', 'not', 'a', 'of', 'but', 'in', 'by', 'on', 'are', 'it', 'if','what','where','how','when']
new_stop_words2=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now','even','until','then']

from stemming.porter2 import stem
from nltk import PorterStemmer
from nltk.stem.porter import *
from nltk.stem.snowball import SnowballStemmer
#stemmer = PorterStemmer()
stemmer = SnowballStemmer("english", ignore_stopwords=True)
def remove_stopword_sentences(str):
    tokenizer = RegexpTokenizer("[\w']+")
    words=tokenizer.tokenize(str)
    english_stops = set(stopwords.words('english'))
    stems=[]
    list_word=[word for word in words if word.lower() not in english_stops and word.lower() not in new_stop_words and word.lower() not in new_stop_words2]
    for word in list_word:
        #stems.append(stem(word))
        #stems.append(PorterStemmer().stem(word))
        #stems.append(stemmer.stem(word))
        #stems.append(stemmer.stem("computer"))
        stems.append(word)
    
    return stems#(stem(setem_word for setem_word in  ([word for word in words if word not in english_stops and word not in new_stop_words])))

# %%
words=remove_stopword_sentences(setnences[3])
count = Counter(words)
# to count words
#print (count.most_common(10))
print(words)
print(count)
# Out:
# ['Nowadays', 'practically', 'everyone', 'computer', 'user', 'many', 'people', 'even', 'computer', 'programmers']
# Counter({'computer': 2, 'even': 1, 'practically': 1, 'user': 1, 'programmers': 1, 'everyone': 1, 'Nowadays': 1, 'many': 1, 'people': 1})

# %% [markdown]
# # Compute Frequencies

# %%
def compute_freq(word_vec):
    headers=["Freq"]
    
    word_nonfreq={}
    
    for index in range(len(word_vec)):
        #word_nonfreq.append(word)
        
        for index2 in range(len(word_vec)):
            counter=0
            if index2+1 in range(len(word_vec)):
                print (word_vec[index],word_vec[index2+1])
                if word_vec[index]==word_vec[index2+1]:
                    counter+=1
        word_nonfreq[ word_vec[index]]=counter
        print(counter)
        #df_frequencies.loc[word]=counter
    df_frequencies = pd.DataFrame(word_nonfreq,index=headers, columns=word_nonfreq ) 
    
    
    return df_frequencies


def count_freq(word_vec):
    headers=["Freq"]
    count = Counter(word_vec)
    df_frequencies = pd.DataFrame(count,index=headers, columns=count ) 
    #print(count)
    
    return df_frequencies
            
#ss=compute_freq(words)
xx=count_freq(words)
xx
#list(xx)
#ss
# Out:
#       even  practically  user  programmers  computer  everyone  Nowadays  \
# Freq     1            1     1            1         2         1         1
#
#       many  people
# Freq     1       1

# %% [markdown]
# ## Word Sense Disambiguation (WSD): LESK per Sentence
# Given an ambiguous word and the context in which the word occurs, Lesk returns a Synset with the highest number of overlapping words between the context sentence and different definitions from each Synset.

# %%
from nltk.wsd import lesk
'''
this function for compute lesk for each word(list of word) in sentence
'''
def lesk_words_sentence(words,sentence):
    lesks= []
    for word in words:
        if lesk(sentence,word, 'n') is not None:
            lesks.append(lesk(sentence,word, 'n'))
            #print("Word is: ",word,"\n LESK: ",lesk(sentence,word, 'n'),"\n Sentence: ",sentence )
        
    return lesks

# %%
'''
this function for compute lesk of word in sentence
'''

def lesk_word_sentence(word,sentence):
    #lesks= []
    #for word in words:
    lesk_synset=lesk(sentence,word, 'n')
        #print("Word is: ",word,"\n LESK: ",lesk(sentence,word, 'n'),"\n Sentence: ",sentence )
        
    return lesk_synset

# %%
lesks=lesk_words_sentence(words,setnences[0])
leskss=lesk_word_sentence(words[1],setnences[0])
#print(words[1],setnences[0])
#print (leskss)

# %%
#type(lesks)

# %% [markdown]
# ## Calculating WordNet Synset similarity using information content

# %%
from nltk.corpus import wordnet as wn
from nltk.corpus import wordnet_ic as wnic
from nltk.tokenize import word_tokenize

'''
this function for compute similarty between 2 synset 
'''

def similarity_by_infocontent(sense1, sense2, option):
    """ Returns similarity scores by information content. """
    #if sense1.pos != sense2.pos: # infocontent sim can't do diff POS.
        #return 0

    info_contents = ['ic-bnc-add1.dat', 'ic-bnc-resnik-add1.dat', 
                     'ic-bnc-resnik.dat', 'ic-bnc.dat', 

                     'ic-brown-add1.dat', 'ic-brown-resnik-add1.dat', 
                     'ic-brown-resnik.dat', 'ic-brown.dat', 

                     'ic-semcor-add1.dat', 'ic-semcor.dat',

                     'ic-semcorraw-add1.dat', 'ic-semcorraw-resnik-add1.dat', 
                     'ic-semcorraw-resnik.dat', 'ic-semcorraw.dat', 

                     'ic-shaks-add1.dat', 'ic-shaks-resnik.dat', 
                     'ic-shaks-resnink-add1.dat', 'ic-shaks.dat', 

                     'ic-treebank-add1.dat', 'ic-treebank-resnik-add1.dat', 
                     'ic-treebank-resnik.dat', 'ic-treebank.dat']

    if option in ['res', 'resnik']:
        #return wn.res_similarity(sense1, sense2, wnic.ic('ic-bnc-resnik-add1.dat'))
        return wn.res_similarity(sense1, sense2, wnic.ic('ic-treebank-resnik-add1.dat'))
    #return min(wn.res_similarity(sense1, sense2, wnic.ic(ic)) \
    #             for ic in info_contents)

    elif option in ['jcn', "jiang-conrath"]:
        #return wn.jcn_similarity(sense1, sense2, wnic.ic('ic-bnc-add1.dat'))
        return wn.jcn_similarity(sense1, sense2, wnic.ic('ic-treebank.dat'))

    elif option in ['lin']:
        #return wn.lin_similarity(sense1, sense2, wnic.ic('ic-bnc-add1.dat'))
        return wn.lin_similarity(sense1, sense2, wnic.ic('ic-treebank.dat'))

def sim(sense1, sense2, option="path"):
    """ Calculates similarity based on user's choice. """
    option = option.lower()
    if option.lower() in ["path", "path_similarity", 
                        "wup", "wupa", "wu-palmer", "wu-palmer",
                        'lch', "leacock-chordorow"]:
        return similarity_by_path(sense1, sense2, option) 
    elif option.lower() in ["res", "resnik",
                          "jcn","jiang-conrath",
                          "lin"]:
        return similarity_by_infocontent(sense1, sense2, option)

def max_similarity(context_sentence, ambiguous_word, option="path", 
                   pos=None, best=True):
    """
    Perform WSD by maximizing the sum of maximum similarity between possible 
    synsets of all words in the context sentence and the possible synsets of the 
    ambiguous words (see http://goo.gl/XMq2BI):
    {argmax}_{synset(a)}(\sum_{i}^{n}{{max}_{synset(i)}(sim(i,a))}
    """
    result = {}
    for i in wn.synsets(ambiguous_word):
        try:
            if pos and pos != str(i.pos()):
                continue
        except:
            if pos and pos != str(i.pos):
                continue
        result[i] = sum(max([sim(i,k,option) for k in wn.synsets(j)]+[0]) \
                        for j in word_tokenize(context_sentence))

    if option in ["res","resnik"]: # lower score = more similar
        result = sorted([(v,k) for k,v in result.items()])
    else: # higher score = more similar
        result = sorted([(v,k) for k,v in result.items()],reverse=True)
    #print (result)
    if best: return result[0][1];
    return result

# %%
print(lesks[2],lesks[1])
similarity_by_infocontent(lesks[2],lesks[1],'res')
# Out:
# Synset('user.n.01') Synset('computer.n.01')
# 1.5520118749329381

# %%
#wn.res_similarity(lesks[1],lesks[2], wnic.ic('ic-bnc-resnik-add1.dat'))

# %%
#similarity_by_infocontent(lesks[2],lesks[1],'jcn')

# %%
#similarity_by_infocontent(lesks[2],lesks[1],'lin')

# %% [markdown]
# ## Simlarty per Words for Sentence

# %%
#df_sentence_similarty = pd.DataFrame(index=words, columns=words )
#df_sentence_similarty.loc[words[0]]=[1,2,3,4,5,6]
'''
to retrive similarty between list of synset
'''
rows_list = []
def simlarty_perWords(list_words,option):
    for index in range(len(list_words)):
        if index+1 <len(list_words):
            #df_similarty.loc[list_words[index]]
            #print(list_words[index].lowest_common_hypernyms(list_words[index+1]))
            print(list_words[index],list_words[index+1],similarity_by_infocontent(list_words[index],list_words[index+1],option))
            rows_list.append(similarity_by_infocontent(list_words[index],list_words[index+1],option))
    return rows_list

# %%
simlarty_perWords(lesks,'res')
# Out:
# Synset('present.n.01') Synset('computer.n.01') -0.0
# Synset('computer.n.01') Synset('user.n.01') 1.5520118749329381
# Synset('user.n.01') Synset('people.n.03') -0.0
# Synset('people.n.03') Synset('evening.n.01') 0.622354726626253
# Synset('evening.n.01') Synset('computer.n.01') -0.0
# Synset('computer.n.01') Synset('programmer.n.01') 1.5520118749329381
# [-0.0, 1.5520118749329381, -0.0, 0.622354726626253, -0.0, 1.5520118749329381]

# %%
#simlarty_perWords(lesks,'lin')

# %%
#simlarty_perWords(lesks,'jcn')

# %% [markdown]
# # TF-IDF
# TF-IDF stands for "Term Frequency, Inverse Document Frequency". It is a way to score the importance of words (or "terms") in a document based on how frequently they appear across multiple documents.
#
# Intuitively...
# If a word appears frequently in a document, it's important. Give the word a high score.
# But if a word appears in many documents, it's not a unique identifier. Give the word a low score.

# %%
import tfidf
#https://github.com/hrs/python-tf-idf
table = tfidf.tfidf()
table.addDocument("foo", [lesks[0],lesks[1],lesks[3]])
#table.addDocument("bar", ["alpha", "bravo", "charlie", "india", "juliet", "kilo"])
#table.addDocument("baz", ["kilo", "lima", "mike", "november"])

#print (table.similarities ([lesks[0],lesks[1],lesks[3]]))

# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
#df

# %% [markdown]
# # Pragraph Words Similarty

# %%
'''
Compute similartyy per pragraph
'''


def similarty_pragraph(pragraph,option):
    lesk_vec=[]# synset lesk of words per pragraph
    synset_lesk_noDuplicates=[]
    Sentences=pragraph_to_setnences(pragraph)
    for sentence in Sentences:
        Words=remove_stopword_sentences(sentence)
        for word in Words:
            lesk_synset=lesk_word_sentence(word,sentence)
            if lesk_synset is not None:
                lesk_vec.append(lesk_synset)

    #Count Freq
    df_freq=count_freq(lesk_vec)
    #Removing Duplicates
    series=list(df_freq)#pd.Series(data=lesk_vec)
    #series.drop_duplicates()
    synset_lesk_noDuplicates= series#.tolist()    
    df_all_synset_lesk = pd.DataFrame(index=series, columns=series )            
    print ("synset_lesk_noDuplicates",len(synset_lesk_noDuplicates))
    


    for row in range(len(synset_lesk_noDuplicates)):
        try:
            data_row=[]
            for col in range(len(synset_lesk_noDuplicates)):

                    #if row < col:

                    sim=similarity_by_infocontent(series[row],series[col],option)
                    if sim is not None:
                        data_row.append(sim)
                    else:
                        data_row.append(0)
                        #print(len(data_row))


                    #else:

                        #data_row.append("row>col")
                        #print(len(data_row))

            print(series[row])
            df_all_synset_lesk.loc[series[row]]=data_row
        except  Exception as inst:
                data_row.append(0)
                print(type(inst))    # the exception instance
                print(inst.args)     # arguments stored in .args
                print(inst)          # __str__ allows args to be printed directly,
                pass
                #print("Ex")
    return df_all_synset_lesk

# %%
res_df=similarty_pragraph(pragraphs[1],'res')
res_df
#jcn_df.to_csv('df_all_synset_lesk.csv')
# Out:
# synset_lesk_noDuplicates 34
# Synset('design.n.06')
# Synset('user.n.01')
# Synset('solution.n.05')
# Synset('intensifier.n.01')
# Synset('present.n.01')
# Synset('experience.n.03')
# Synset('theory.n.03')
# Synset('side.n.09')
# Synset('reasoning.n.01')
# Synset('evening.n.01')
# Synset('discipline.n.02')
# Synset('trouble.n.01')
# Synset('people.n.03')
# Synset('scientist.n.01')
# Synset('wish.n.01')
# Synset('preciseness.n.02')
# Synset('span.n.04')
# Synset('programmer.n.01')
# Synset('creativity.n.01')
# Synset('must.n.01')
# Synset('outline.n.02')
# Synset('ace.n.03')
# Synset('level.n.05')
# Synset('terminus.n.03')
# Synset('hired_hand.n.01')
# Synset('concrete.n.01')
# Synset('computer_science.n.01')
# Synset('thinking.n.01')
# Synset('resolution.n.04')
# Synset('practice.n.04')
# Synset('modeling.n.02')
# Synset('computer.n.01')
# Synset('science.n.01')
# Synset('acquiring.n.01')
#                                 Synset('design.n.06') Synset('user.n.01')  \
# Synset('design.n.06')                         10.7963             1.55201
# Synset('user.n.01')                           1.55201             6.31468
# Synset('solution.n.05')                            -0                  -0
# Synset('intensifier.n.01')                         -0                  -0
# Synset('present.n.01')                             -0                  -0
# Synset('experience.n.03')                          -0                  -0
# Synset('theory.n.03')                              -0                  -0
# Synset('side.n.09')                          0.769715            0.769715
# Synset('reasoning.n.01')                           -0                  -0
# Synset('evening.n.01')                             -0                  -0
# Synset('discipline.n.02')                          -0                  -0
# Synset('trouble.n.01')                             -0                  -0
# Synset('people.n.03')                              -0                  -0
# Synset('scientist.n.01')                      1.55201             2.22259
# Synset('wish.n.01')                                -0                  -0
# Synset('preciseness.n.02')                         -0                  -0
# Synset('span.n.04')                                -0                  -0
# Synset('programmer.n.01')                     1.55201             2.22259
# Synset('creativity.n.01')                          -0                  -0
# Synset('must.n.01')                          0.769715            0.769715
# Synset('outline.n.02')                             -0                  -0
# Synset('ace.n.03')                            1.55201             2.22259
# Synset('level.n.05')                          2.56104             1.55201
# Synset('terminus.n.03')                       4.91124             1.55201
# Synset('hired_hand.n.01')                     1.55201             2.22259
# Synset('concrete.n.01')                       2.56104             1.55201
# Synset('computer_science.n.01')                    -0                  -0
# Synset('thinking.n.01')                            -0                  -0
# Synset('resolution.n.04')                          -0                  -0
# Synset('practice.n.04')                            -0                  -0
# Synset('modeling.n.02')                            -0                  -0
# Synset('computer.n.01')                       2.56104             1.55201
# Synset('science.n.01')                             -0                  -0
# Synset('acquiring.n.01')                           -0                  -0
#
#                                 Synset('solution.n.05')  \
# Synset('design.n.06')                                -0
# Synset('user.n.01')                                  -0
# Synset('solution.n.05')                         11.1437
# Synset('intensifier.n.01')                     0.622355
# Synset('present.n.01')                         0.622355
# Synset('experience.n.03')                       2.10449
# Synset('theory.n.03')                           1.78127
# Synset('side.n.09')                                  -0
# Synset('reasoning.n.01')                        1.78127
# Synset('evening.n.01')                         0.622355
# Synset('discipline.n.02')                       1.78127
# Synset('trouble.n.01')                          1.78127
# Synset('people.n.03')                          0.622355
# Synset('scientist.n.01')                             -0
# Synset('wish.n.01')                            0.622355
# Synset('preciseness.n.02')                     0.622355
# Synset('span.n.04')                            0.622355
# Synset('programmer.n.01')                            -0
# Synset('creativity.n.01')                       1.78127
# Synset('must.n.01')                                  -0
# Synset('outline.n.02')                         0.622355
# Synset('ace.n.03')                                   -0
# Synset('level.n.05')                                 -0
# Synset('terminus.n.03')                        0.622355
# Synset('hired_hand.n.01')                            -0
# Synset('concrete.n.01')                              -0
# Synset('computer_science.n.01')                 1.78127
# Synset('thinking.n.01')                         1.78127
# Synset('resolution.n.04')                       2.43222
# Synset('practice.n.04')                         2.43222
# Synset('modeling.n.02')                         2.43222
# Synset('computer.n.01')                              -0
# Synset('science.n.01')                          1.78127
# Synset('acquiring.n.01')                        2.43222
#
#                                 Synset('intensifier.n.01')  \
# Synset('design.n.06')                                   -0
# Synset('user.n.01')                                     -0
# Synset('solution.n.05')                           0.622355
# Synset('intensifier.n.01')                         10.8152
# Synset('present.n.01')                            0.622355
# Synset('experience.n.03')                         0.622355
# Synset('theory.n.03')                             0.622355
# Synset('side.n.09')                                     -0
# Synset('reasoning.n.01')                          0.622355
# Synset('evening.n.01')                            0.622355
# Synset('discipline.n.02')                         0.622355
# Synset('trouble.n.01')                            0.622355
# Synset('people.n.03')                             0.622355
# Synset('scientist.n.01')                                -0
# Synset('wish.n.01')                               0.622355
# Synset('preciseness.n.02')                        0.622355
# Synset('span.n.04')                               0.622355
# Synset('programmer.n.01')                               -0
# Synset('creativity.n.01')                         0.622355
# Synset('must.n.01')                                     -0
# Synset('outline.n.02')                            0.622355
# Synset('ace.n.03')                                      -0
# Synset('level.n.05')                                    -0
# Synset('terminus.n.03')                           0.622355
# Synset('hired_hand.n.01')                               -0
# Synset('concrete.n.01')                                 -0
# Synset('computer_science.n.01')                   0.622355
# Synset('thinking.n.01')                           0.622355
# Synset('resolution.n.04')                         0.622355
# Synset('practice.n.04')                           0.622355
# Synset('modeling.n.02')                           0.622355
# Synset('computer.n.01')                                 -0
# Synset('science.n.01')                            0.622355
# Synset('acquiring.n.01')                          0.622355
#
#                                 Synset('present.n.01')  \
# Synset('design.n.06')                               -0
# Synset('user.n.01')                                 -0
# Synset('solution.n.05')                       0.622355
# Synset('intensifier.n.01')                    0.622355
# Synset('present.n.01')                         6.27567
# Synset('experience.n.03')                     0.622355
# Synset('theory.n.03')                         0.622355
# Synset('side.n.09')                                 -0
# Synset('reasoning.n.01')                      0.622355
# Synset('evening.n.01')                        0.622355
# Synset('discipline.n.02')                     0.622355
# Synset('trouble.n.01')                        0.622355
# Synset('people.n.03')                         0.622355
# Synset('scientist.n.01')                            -0
# Synset('wish.n.01')                             2.5661
# Synset('preciseness.n.02')                      2.5661
# Synset('span.n.04')                           0.622355
# Synset('programmer.n.01')                           -0
# Synset('creativity.n.01')                     0.622355
# Synset('must.n.01')                                 -0
# Synset('outline.n.02')                        0.622355
# Synset('ace.n.03')                                  -0
# Synset('level.n.05')                                -0
# Synset('terminus.n.03')                         2.5661
# Synset('hired_hand.n.01')                           -0
# Synset('concrete.n.01')                             -0
# Synset('computer_science.n.01')               0.622355
# Synset('thinking.n.01')                       0.622355
# Synset('resolution.n.04')                     0.622355
# Synset('practice.n.04')                       0.622355
# Synset('modeling.n.02')                       0.622355
# Synset('computer.n.01')                             -0
# Synset('science.n.01')                        0.622355
# Synset('acquiring.n.01')                      0.622355
#
#                                 Synset('experience.n.03')  \
# Synset('design.n.06')                                  -0
# Synset('user.n.01')                                    -0
# Synset('solution.n.05')                           2.10449
# Synset('intensifier.n.01')                       0.622355
# Synset('present.n.01')                           0.622355
# Synset('experience.n.03')                         7.76765
# Synset('theory.n.03')                             1.78127
# Synset('side.n.09')                                    -0
# Synset('reasoning.n.01')                          1.78127
# Synset('evening.n.01')                           0.622355
# Synset('discipline.n.02')                         1.78127
# Synset('trouble.n.01')                            1.78127
# Synset('people.n.03')                            0.622355
# Synset('scientist.n.01')                               -0
# Synset('wish.n.01')                              0.622355
# Synset('preciseness.n.02')                       0.622355
# Synset('span.n.04')                              0.622355
# Synset('programmer.n.01')                              -0
# Synset('creativity.n.01')                         1.78127
# Synset('must.n.01')                                    -0
# Synset('outline.n.02')                           0.622355
# Synset('ace.n.03')                                     -0
# Synset('level.n.05')                                   -0
# Synset('terminus.n.03')                          0.622355
# Synset('hired_hand.n.01')                              -0
# Synset('concrete.n.01')                                -0
# Synset('computer_science.n.01')                   1.78127
# Synset('thinking.n.01')                           1.78127
# Synset('resolution.n.04')                         2.10449
# Synset('practice.n.04')                           2.10449
# Synset('modeling.n.02')                           2.10449
# Synset('computer.n.01')                                -0
# Synset('science.n.01')                            1.78127
# Synset('acquiring.n.01')                          2.10449
#
#                                 Synset('theory.n.03') Synset('side.n.09')  \
# Synset('design.n.06')                              -0            0.769715
# Synset('user.n.01')                                -0            0.769715
# Synset('solution.n.05')                       1.78127                  -0
# Synset('intensifier.n.01')                   0.622355                  -0
# Synset('present.n.01')                       0.622355                  -0
# Synset('experience.n.03')                     1.78127                  -0
# Synset('theory.n.03')                         10.5192                  -0
# Synset('side.n.09')                                -0             10.3769
# Synset('reasoning.n.01')                      3.08626                  -0
# Synset('evening.n.01')                       0.622355                  -0
# Synset('discipline.n.02')                     3.08626                  -0
# Synset('trouble.n.01')                        3.08626                  -0
# Synset('people.n.03')                        0.622355                  -0
# Synset('scientist.n.01')                           -0            0.769715
# Synset('wish.n.01')                          0.622355                  -0
# Synset('preciseness.n.02')                   0.622355                  -0
# Synset('span.n.04')                          0.622355                  -0
# Synset('programmer.n.01')                          -0            0.769715
# Synset('creativity.n.01')                     3.08626                  -0
# Synset('must.n.01')                                -0            0.769715
# Synset('outline.n.02')                       0.622355                  -0
# Synset('ace.n.03')                                 -0            0.769715
# Synset('level.n.05')                               -0            0.769715
# Synset('terminus.n.03')                      0.622355            0.769715
# Synset('hired_hand.n.01')                          -0            0.769715
# Synset('concrete.n.01')                            -0            0.769715
# Synset('computer_science.n.01')               3.70023                  -0
# Synset('thinking.n.01')                       3.08626                  -0
# Synset('resolution.n.04')                     1.78127                  -0
# Synset('practice.n.04')                       1.78127                  -0
# Synset('modeling.n.02')                       3.70023                  -0
# Synset('computer.n.01')                            -0            0.769715
# Synset('science.n.01')                        3.70023                  -0
# Synset('acquiring.n.01')                      1.78127                  -0
#
#                                 Synset('reasoning.n.01')  \
# Synset('design.n.06')                                 -0
# Synset('user.n.01')                                   -0
# Synset('solution.n.05')                          1.78127
# Synset('intensifier.n.01')                      0.622355
# Synset('present.n.01')                          0.622355
# Synset('experience.n.03')                        1.78127
# Synset('theory.n.03')                            3.08626
# Synset('side.n.09')                                   -0
# Synset('reasoning.n.01')                         7.15721
# Synset('evening.n.01')                          0.622355
# Synset('discipline.n.02')                        3.08626
# Synset('trouble.n.01')                           3.08626
# Synset('people.n.03')                           0.622355
# Synset('scientist.n.01')                              -0
# Synset('wish.n.01')                             0.622355
# Synset('preciseness.n.02')                      0.622355
# Synset('span.n.04')                             0.622355
# Synset('programmer.n.01')                             -0
# Synset('creativity.n.01')                        3.08626
# Synset('must.n.01')                                   -0
# Synset('outline.n.02')                          0.622355
# Synset('ace.n.03')                                    -0
# Synset('level.n.05')                                  -0
# Synset('terminus.n.03')                         0.622355
# Synset('hired_hand.n.01')                             -0
# Synset('concrete.n.01')                               -0
# Synset('computer_science.n.01')                  3.08626
# Synset('thinking.n.01')                          5.83391
# Synset('resolution.n.04')                        1.78127
# Synset('practice.n.04')                          1.78127
# Synset('modeling.n.02')                          3.08626
# Synset('computer.n.01')                               -0
# Synset('science.n.01')                           3.08626
# Synset('acquiring.n.01')                         1.78127
#
#                                 Synset('evening.n.01')  \
# Synset('design.n.06')                               -0
# Synset('user.n.01')                                 -0
# Synset('solution.n.05')                       0.622355
# Synset('intensifier.n.01')                    0.622355
# Synset('present.n.01')                        0.622355
# Synset('experience.n.03')                     0.622355
# Synset('theory.n.03')                         0.622355
# Synset('side.n.09')                                 -0
# Synset('reasoning.n.01')                      0.622355
# Synset('evening.n.01')                          6.6549
# Synset('discipline.n.02')                     0.622355
# Synset('trouble.n.01')                        0.622355
# Synset('people.n.03')                         0.622355
# Synset('scientist.n.01')                            -0
# Synset('wish.n.01')                           0.622355
# Synset('preciseness.n.02')                    0.622355
# Synset('span.n.04')                            2.35784
# Synset('programmer.n.01')                           -0
# Synset('creativity.n.01')                     0.622355
# Synset('must.n.01')                                 -0
# Synset('outline.n.02')                        0.622355
# Synset('ace.n.03')                                  -0
# Synset('level.n.05')                                -0
# Synset('terminus.n.03')                       0.622355
# Synset('hired_hand.n.01')                           -0
# Synset('concrete.n.01')                             -0
# Synset('computer_science.n.01')               0.622355
# Synset('thinking.n.01')                       0.622355
# Synset('resolution.n.04')                     0.622355
# Synset('practice.n.04')                       0.622355
# Synset('modeling.n.02')                       0.622355
# Synset('computer.n.01')                             -0
# Synset('science.n.01')                        0.622355
# Synset('acquiring.n.01')                      0.622355
#
#                                           ...             \
# Synset('design.n.06')                     ...
# Synset('user.n.01')                       ...
# Synset('solution.n.05')                   ...
# Synset('intensifier.n.01')                ...
# Synset('present.n.01')                    ...
# Synset('experience.n.03')                 ...
# Synset('theory.n.03')                     ...
# Synset('side.n.09')                       ...
# Synset('reasoning.n.01')                  ...
# Synset('evening.n.01')                    ...
# Synset('discipline.n.02')                 ...
# Synset('trouble.n.01')                    ...
# Synset('people.n.03')                     ...
# Synset('scientist.n.01')                  ...
# Synset('wish.n.01')                       ...
# Synset('preciseness.n.02')                ...
# Synset('span.n.04')                       ...
# Synset('programmer.n.01')                 ...
# Synset('creativity.n.01')                 ...
# Synset('must.n.01')                       ...
# Synset('outline.n.02')                    ...
# Synset('ace.n.03')                        ...
# Synset('level.n.05')                      ...
# Synset('terminus.n.03')                   ...
# Synset('hired_hand.n.01')                 ...
# Synset('concrete.n.01')                   ...
# Synset('computer_science.n.01')           ...
# Synset('thinking.n.01')                   ...
# Synset('resolution.n.04')                 ...
# Synset('practice.n.04')                   ...
# Synset('modeling.n.02')                   ...
# Synset('computer.n.01')                   ...
# Synset('science.n.01')                    ...
# Synset('acquiring.n.01')                  ...
#
#                                 Synset('hired_hand.n.01')  \
# Synset('design.n.06')                             1.55201
# Synset('user.n.01')                               2.22259
# Synset('solution.n.05')                                -0
# Synset('intensifier.n.01')                             -0
# Synset('present.n.01')                                 -0
# Synset('experience.n.03')                              -0
# Synset('theory.n.03')                                  -0
# Synset('side.n.09')                              0.769715
# Synset('reasoning.n.01')                               -0
# Synset('evening.n.01')                                 -0
# Synset('discipline.n.02')                              -0
# Synset('trouble.n.01')                                 -0
# Synset('people.n.03')                                  -0
# Synset('scientist.n.01')                          2.22259
# Synset('wish.n.01')                                    -0
# Synset('preciseness.n.02')                             -0
# Synset('span.n.04')                                    -0
# Synset('programmer.n.01')                         2.22259
# Synset('creativity.n.01')                              -0
# Synset('must.n.01')                              0.769715
# Synset('outline.n.02')                                 -0
# Synset('ace.n.03')                                2.22259
# Synset('level.n.05')                              1.55201
# Synset('terminus.n.03')                           1.55201
# Synset('hired_hand.n.01')                         9.57611
# Synset('concrete.n.01')                           1.55201
# Synset('computer_science.n.01')                        -0
# Synset('thinking.n.01')                                -0
# Synset('resolution.n.04')                              -0
# Synset('practice.n.04')                                -0
# Synset('modeling.n.02')                                -0
# Synset('computer.n.01')                           1.55201
# Synset('science.n.01')                                 -0
# Synset('acquiring.n.01')                               -0
#
#                                 Synset('concrete.n.01')  \
# Synset('design.n.06')                           2.56104
# Synset('user.n.01')                             1.55201
# Synset('solution.n.05')                              -0
# Synset('intensifier.n.01')                           -0
# Synset('present.n.01')                               -0
# Synset('experience.n.03')                            -0
# Synset('theory.n.03')                                -0
# Synset('side.n.09')                            0.769715
# Synset('reasoning.n.01')                             -0
# Synset('evening.n.01')                               -0
# Synset('discipline.n.02')                            -0
# Synset('trouble.n.01')                               -0
# Synset('people.n.03')                                -0
# Synset('scientist.n.01')                        1.55201
# Synset('wish.n.01')                                  -0
# Synset('preciseness.n.02')                           -0
# Synset('span.n.04')                                  -0
# Synset('programmer.n.01')                       1.55201
# Synset('creativity.n.01')                            -0
# Synset('must.n.01')                            0.769715
# Synset('outline.n.02')                               -0
# Synset('ace.n.03')                              1.55201
# Synset('level.n.05')                            2.56104
# Synset('terminus.n.03')                         2.56104
# Synset('hired_hand.n.01')                       1.55201
# Synset('concrete.n.01')                         9.81946
# Synset('computer_science.n.01')                      -0
# Synset('thinking.n.01')                              -0
# Synset('resolution.n.04')                            -0
# Synset('practice.n.04')                              -0
# Synset('modeling.n.02')                              -0
# Synset('computer.n.01')                         2.56104
# Synset('science.n.01')                               -0
# Synset('acquiring.n.01')                             -0
#
#                                 Synset('computer_science.n.01')  \
# Synset('design.n.06')                                        -0
# Synset('user.n.01')                                          -0
# Synset('solution.n.05')                                 1.78127
# Synset('intensifier.n.01')                             0.622355
# Synset('present.n.01')                                 0.622355
# Synset('experience.n.03')                               1.78127
# Synset('theory.n.03')                                   3.70023
# Synset('side.n.09')                                          -0
# Synset('reasoning.n.01')                                3.08626
# Synset('evening.n.01')                                 0.622355
# Synset('discipline.n.02')                               3.08626
# Synset('trouble.n.01')                                  3.08626
# Synset('people.n.03')                                  0.622355
# Synset('scientist.n.01')                                     -0
# Synset('wish.n.01')                                    0.622355
# Synset('preciseness.n.02')                             0.622355
# Synset('span.n.04')                                    0.622355
# Synset('programmer.n.01')                                    -0
# Synset('creativity.n.01')                               3.08626
# Synset('must.n.01')                                          -0
# Synset('outline.n.02')                                 0.622355
# Synset('ace.n.03')                                           -0
# Synset('level.n.05')                                         -0
# Synset('terminus.n.03')                                0.622355
# Synset('hired_hand.n.01')                                    -0
# Synset('concrete.n.01')                                      -0
# Synset('computer_science.n.01')                         10.3834
# Synset('thinking.n.01')                                 3.08626
# Synset('resolution.n.04')                               1.78127
# Synset('practice.n.04')                                 1.78127
# Synset('modeling.n.02')                                 5.52902
# Synset('computer.n.01')                                      -0
# Synset('science.n.01')                                  5.52902
# Synset('acquiring.n.01')                                1.78127
#
#                                 Synset('thinking.n.01')  \
# Synset('design.n.06')                                -0
# Synset('user.n.01')                                  -0
# Synset('solution.n.05')                         1.78127
# Synset('intensifier.n.01')                     0.622355
# Synset('present.n.01')                         0.622355
# Synset('experience.n.03')                       1.78127
# Synset('theory.n.03')                           3.08626
# Synset('side.n.09')                                  -0
# Synset('reasoning.n.01')                        5.83391
# Synset('evening.n.01')                         0.622355
# Synset('discipline.n.02')                       3.08626
# Synset('trouble.n.01')                          3.08626
# Synset('people.n.03')                          0.622355
# Synset('scientist.n.01')                             -0
# Synset('wish.n.01')                            0.622355
# Synset('preciseness.n.02')                     0.622355
# Synset('span.n.04')                            0.622355
# Synset('programmer.n.01')                            -0
# Synset('creativity.n.01')                       3.08626
# Synset('must.n.01')                                  -0
# Synset('outline.n.02')                         0.622355
# Synset('ace.n.03')                                   -0
# Synset('level.n.05')                                 -0
# Synset('terminus.n.03')                        0.622355
# Synset('hired_hand.n.01')                            -0
# Synset('concrete.n.01')                              -0
# Synset('computer_science.n.01')                 3.08626
# Synset('thinking.n.01')                         5.83391
# Synset('resolution.n.04')                       1.78127
# Synset('practice.n.04')                         1.78127
# Synset('modeling.n.02')                         3.08626
# Synset('computer.n.01')                              -0
# Synset('science.n.01')                          3.08626
# Synset('acquiring.n.01')                        1.78127
#
#                                 Synset('resolution.n.04')  \
# Synset('design.n.06')                                  -0
# Synset('user.n.01')                                    -0
# Synset('solution.n.05')                           2.43222
# Synset('intensifier.n.01')                       0.622355
# Synset('present.n.01')                           0.622355
# Synset('experience.n.03')                         2.10449
# Synset('theory.n.03')                             1.78127
# Synset('side.n.09')                                    -0
# Synset('reasoning.n.01')                          1.78127
# Synset('evening.n.01')                           0.622355
# Synset('discipline.n.02')                         1.78127
# Synset('trouble.n.01')                            1.78127
# Synset('people.n.03')                            0.622355
# Synset('scientist.n.01')                               -0
# Synset('wish.n.01')                              0.622355
# Synset('preciseness.n.02')                       0.622355
# Synset('span.n.04')                              0.622355
# Synset('programmer.n.01')                              -0
# Synset('creativity.n.01')                         1.78127
# Synset('must.n.01')                                    -0
# Synset('outline.n.02')                           0.622355
# Synset('ace.n.03')                                     -0
# Synset('level.n.05')                                   -0
# Synset('terminus.n.03')                          0.622355
# Synset('hired_hand.n.01')                              -0
# Synset('concrete.n.01')                                -0
# Synset('computer_science.n.01')                   1.78127
# Synset('thinking.n.01')                           1.78127
# Synset('resolution.n.04')                         10.9038
# Synset('practice.n.04')                           2.43222
# Synset('modeling.n.02')                           2.43222
# Synset('computer.n.01')                                -0
# Synset('science.n.01')                            1.78127
# Synset('acquiring.n.01')                          2.43222
#
#                                 Synset('practice.n.04')  \
# Synset('design.n.06')                                -0
# Synset('user.n.01')                                  -0
# Synset('solution.n.05')                         2.43222
# Synset('intensifier.n.01')                     0.622355
# Synset('present.n.01')                         0.622355
# Synset('experience.n.03')                       2.10449
# Synset('theory.n.03')                           1.78127
# Synset('side.n.09')                                  -0
# Synset('reasoning.n.01')                        1.78127
# Synset('evening.n.01')                         0.622355
# Synset('discipline.n.02')                       1.78127
# Synset('trouble.n.01')                          1.78127
# Synset('people.n.03')                          0.622355
# Synset('scientist.n.01')                             -0
# Synset('wish.n.01')                            0.622355
# Synset('preciseness.n.02')                     0.622355
# Synset('span.n.04')                            0.622355
# Synset('programmer.n.01')                            -0
# Synset('creativity.n.01')                       1.78127
# Synset('must.n.01')                                  -0
# Synset('outline.n.02')                         0.622355
# Synset('ace.n.03')                                   -0
# Synset('level.n.05')                                 -0
# Synset('terminus.n.03')                        0.622355
# Synset('hired_hand.n.01')                            -0
# Synset('concrete.n.01')                              -0
# Synset('computer_science.n.01')                 1.78127
# Synset('thinking.n.01')                         1.78127
# Synset('resolution.n.04')                       2.43222
# Synset('practice.n.04')                         9.59533
# Synset('modeling.n.02')                         3.39586
# Synset('computer.n.01')                              -0
# Synset('science.n.01')                          1.78127
# Synset('acquiring.n.01')                        2.43222
#
#                                 Synset('modeling.n.02')  \
# Synset('design.n.06')                                -0
# Synset('user.n.01')                                  -0
# Synset('solution.n.05')                         2.43222
# Synset('intensifier.n.01')                     0.622355
# Synset('present.n.01')                         0.622355
# Synset('experience.n.03')                       2.10449
# Synset('theory.n.03')                           3.70023
# Synset('side.n.09')                                  -0
# Synset('reasoning.n.01')                        3.08626
# Synset('evening.n.01')                         0.622355
# Synset('discipline.n.02')                       3.08626
# Synset('trouble.n.01')                          3.08626
# Synset('people.n.03')                          0.622355
# Synset('scientist.n.01')                             -0
# Synset('wish.n.01')                            0.622355
# Synset('preciseness.n.02')                     0.622355
# Synset('span.n.04')                            0.622355
# Synset('programmer.n.01')                            -0
# Synset('creativity.n.01')                       3.08626
# Synset('must.n.01')                                  -0
# Synset('outline.n.02')                         0.622355
# Synset('ace.n.03')                                   -0
# Synset('level.n.05')                                 -0
# Synset('terminus.n.03')                        0.622355
# Synset('hired_hand.n.01')                            -0
# Synset('concrete.n.01')                              -0
# Synset('computer_science.n.01')                 5.52902
# Synset('thinking.n.01')                         3.08626
# Synset('resolution.n.04')                       2.43222
# Synset('practice.n.04')                         3.39586
# Synset('modeling.n.02')                         12.8991
# Synset('computer.n.01')                              -0
# Synset('science.n.01')                          5.52902
# Synset('acquiring.n.01')                        2.43222
#
#                                 Synset('computer.n.01')  \
# Synset('design.n.06')                           2.56104
# Synset('user.n.01')                             1.55201
# Synset('solution.n.05')                              -0
# Synset('intensifier.n.01')                           -0
# Synset('present.n.01')                               -0
# Synset('experience.n.03')                            -0
# Synset('theory.n.03')                                -0
# Synset('side.n.09')                            0.769715
# Synset('reasoning.n.01')                             -0
# Synset('evening.n.01')                               -0
# Synset('discipline.n.02')                            -0
# Synset('trouble.n.01')                               -0
# Synset('people.n.03')                                -0
# Synset('scientist.n.01')                        1.55201
# Synset('wish.n.01')                                  -0
# Synset('preciseness.n.02')                           -0
# Synset('span.n.04')                                  -0
# Synset('programmer.n.01')                       1.55201
# Synset('creativity.n.01')                            -0
# Synset('must.n.01')                            0.769715
# Synset('outline.n.02')                               -0
# Synset('ace.n.03')                              1.55201
# Synset('level.n.05')                            4.20865
# Synset('terminus.n.03')                         2.56104
# Synset('hired_hand.n.01')                       1.55201
# Synset('concrete.n.01')                         2.56104
# Synset('computer_science.n.01')                      -0
# Synset('thinking.n.01')                              -0
# Synset('resolution.n.04')                            -0
# Synset('practice.n.04')                              -0
# Synset('modeling.n.02')                              -0
# Synset('computer.n.01')                         6.87127
# Synset('science.n.01')                               -0
# Synset('acquiring.n.01')                             -0
#
#                                 Synset('science.n.01')  \
# Synset('design.n.06')                               -0
# Synset('user.n.01')                                 -0
# Synset('solution.n.05')                        1.78127
# Synset('intensifier.n.01')                    0.622355
# Synset('present.n.01')                        0.622355
# Synset('experience.n.03')                      1.78127
# Synset('theory.n.03')                          3.70023
# Synset('side.n.09')                                 -0
# Synset('reasoning.n.01')                       3.08626
# Synset('evening.n.01')                        0.622355
# Synset('discipline.n.02')                      3.08626
# Synset('trouble.n.01')                         3.08626
# Synset('people.n.03')                         0.622355
# Synset('scientist.n.01')                            -0
# Synset('wish.n.01')                           0.622355
# Synset('preciseness.n.02')                    0.622355
# Synset('span.n.04')                           0.622355
# Synset('programmer.n.01')                           -0
# Synset('creativity.n.01')                      3.08626
# Synset('must.n.01')                                 -0
# Synset('outline.n.02')                        0.622355
# Synset('ace.n.03')                                  -0
# Synset('level.n.05')                                -0
# Synset('terminus.n.03')                       0.622355
# Synset('hired_hand.n.01')                           -0
# Synset('concrete.n.01')                             -0
# Synset('computer_science.n.01')                5.52902
# Synset('thinking.n.01')                        3.08626
# Synset('resolution.n.04')                      1.78127
# Synset('practice.n.04')                        1.78127
# Synset('modeling.n.02')                        5.52902
# Synset('computer.n.01')                             -0
# Synset('science.n.01')                            6.42
# Synset('acquiring.n.01')                       1.78127
#
#                                 Synset('acquiring.n.01')
# Synset('design.n.06')                                 -0
# Synset('user.n.01')                                   -0
# Synset('solution.n.05')                          2.43222
# Synset('intensifier.n.01')                      0.622355
# Synset('present.n.01')                          0.622355
# Synset('experience.n.03')                        2.10449
# Synset('theory.n.03')                            1.78127
# Synset('side.n.09')                                   -0
# Synset('reasoning.n.01')                         1.78127
# Synset('evening.n.01')                          0.622355
# Synset('discipline.n.02')                        1.78127
# Synset('trouble.n.01')                           1.78127
# Synset('people.n.03')                           0.622355
# Synset('scientist.n.01')                              -0
# Synset('wish.n.01')                             0.622355
# Synset('preciseness.n.02')                      0.622355
# Synset('span.n.04')                             0.622355
# Synset('programmer.n.01')                             -0
# Synset('creativity.n.01')                        1.78127
# Synset('must.n.01')                                   -0
# Synset('outline.n.02')                          0.622355
# Synset('ace.n.03')                                    -0
# Synset('level.n.05')                                  -0
# Synset('terminus.n.03')                         0.622355
# Synset('hired_hand.n.01')                             -0
# Synset('concrete.n.01')                               -0
# Synset('computer_science.n.01')                  1.78127
# Synset('thinking.n.01')                          1.78127
# Synset('resolution.n.04')                        2.43222
# Synset('practice.n.04')                          2.43222
# Synset('modeling.n.02')                          2.43222
# Synset('computer.n.01')                               -0
# Synset('science.n.01')                           1.78127
# Synset('acquiring.n.01')                         6.16974
#
# [34 rows x 34 columns]

# %%
jcn_df=similarty_pragraph(pragraphs[1],'jcn')
jcn_df

# %%
lin_df=similarty_pragraph(pragraphs[0],'lin')
lin_df

# %% [markdown]
# # Data Visualization

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot') 
import numpy as np
#import bokeh.charts as bc
#import bokeh.plotting as bk

# %%
jcn_df.plot(title='jcn_df')

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])

jcn_df.plot.scatter(x='a', y='b');

# %%
ax = df.plot.scatter(x='a', y='b', color='DarkBlue', label='Group 1');
df.plot.scatter(x='c', y='d', color='DarkGreen', label='Group 2', ax=ax);

# %%
jcn_df.plot.scatter(x='a', y='b', c='c', s=50);

# %%
jcn_df.plot(style=['o','rx','kk'])

# %%
import nltk
from collections import Counter
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot') 
import numpy as np

# %% [markdown]
# # Read File

# %%
new_path = '/home/cloudera/cs2.txt'
def read_file(str):
    file = open(str,'r')
    txt=file.read()
    #print(txt)
    return txt

# %%
txt=read_file(new_path)

# %%
type(txt)
# Out:
# str

# %% [markdown]
# # Split text to pragraphs

# %%
def txt_pragraphs(str):
    pragraphs = str.split("\n\n")
    return pragraphs
pragraphs=txt_pragraphs(txt)
type(pragraphs)
# Out:
# list

# %%
n_pragraph=0
pragraphs[n_pragraph]
# Out:
# "Computer science is a discipline that spans theory and practice. It requires thinking both in abstract terms and in concrete terms. The practical side of computing can be seen everywhere. Nowadays, practically everyone is a computer user, and many people are even computer programmers.Getting computers to do what you want them to do requires intensive hands-on experience. But computer science can be seen on a higher level, as a science of problem solving. Computer scientists must be adept at modeling and analyzing problems. They must also be able to design solutions and verify that they are correct. Problem solving requires precision, creativity, and careful reasoning.Computer science also has strong connections to other disciplines. Many problems in science, engineering, health care, business, and other areas can be solved effectively with computers, but finding a solution requires both computer science expertise and knowledge of the particular application domain. Thus, computer scientists often become proficient in other subjects.Finally, computer science has a wide range of specialties. These include computer architecture, software systems, graphics, artifical intelligence, computational science, and software engineering. Drawing from a common core of computer science knowledge, each specialty area focuses on particular challenges.Computer Science is practiced by mathematicians, scientists and engineers. Mathematics, the origins of Computer Science, provides reason and logic. Science provides the methodology for learning and refinement. Engineering provides the techniques for building hardware and software.Finally, and most importantly, computer scientists are computer scientists because it is fun. \nComputer Science: The Profession Computer science is a discipline that involves the understanding and design of computers and computational processes. In its most general form it is concerned with the understanding of information transfer and transformation. Particular interest is placed on making processes efficient and endowing them with some form of intelligence. The discipline ranges from theoretical studies of algorithms to practical problems of implementation in terms of computational hardware and software.A central focus is on processes for handling and manipulating information. Thus, the discipline spans both advancing the fundamental understanding of algorithms and information processes in general as well as the practical design of efficient reliable software and hardware to meet given specifications. Computer science is a young discipline that is evolving rapidly from its beginnings in the 1940's. As such it includes theoretical studies, experimental methods, and engineering design all in one discipline. This differs radically from most physical sciences that separate the understanding and advancement of the science from the applications of the science in fields of engineering design and implementation. In computer science there is an inherent intermingling of the theoretical concepts of computability and algorithmic efficiency with the modern practical advancements in electronics that continue to stimulate advances in the discipline. It is this close interaction of the theoretical and design aspects of the field that binds them together into a single discipline."

# %% [markdown]
# # Split Pragraph to Sentences

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
#print(sent_tokenize(pragraphs(txt)[1]))
def pragraph_to_setnences(str):
    return sent_tokenize(str)
setnences=pragraph_to_setnences(pragraphs[n_pragraph])

# %% [markdown]
# ## Word Process For Sentence

# %%
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer

# %% [markdown]
# ## Removing English stopwords and Punct per Sentence

# %%
new_stop_words = ['the', 'that', 'to', 'as', 'there', 'has', 'and', 'or', 'is', 'not', 'a', 'of', 'but', 'in', 'by', 'on', 'are', 'it', 'if','what','where','how','when']
new_stop_words2=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now','even','until','then','must']

from stemming.porter2 import stem
from nltk import PorterStemmer
from nltk.stem.porter import *
from nltk.stem.snowball import SnowballStemmer
#stemmer = PorterStemmer()
stemmer = SnowballStemmer("english", ignore_stopwords=True)
def remove_stopword_sentences(str):
    tokenizer = RegexpTokenizer("[\w']+")
    words=tokenizer.tokenize(str)
    english_stops = set(stopwords.words('english'))
    stems=[]
    list_word=[word for word in words if word.lower() not in english_stops and word.lower() not in new_stop_words and word.lower() not in new_stop_words2]
    for word in list_word:
        #stems.append(stem(word))
        #stems.append(PorterStemmer().stem(word))
        #stems.append(stemmer.stem(word))
        #stems.append(stemmer.stem("computer"))
        stems.append(word)
    
    return stems#(stem(setem_word for setem_word in  ([word for word in words if word not in english_stops and word not in new_stop_words])))

# %%
words=remove_stopword_sentences(setnences[n_pragraph])
count = Counter(words)
# to count words
#print (count.most_common(10))
print(words)
print(count)
# Out:
# ['Computer', 'science', 'discipline', 'spans', 'theory', 'practice']
# Counter({'theory': 1, 'practice': 1, 'science': 1, 'Computer': 1, 'discipline': 1, 'spans': 1})

# %% [markdown]
# # Compute Frequencies

# %%
def compute_freq(word_vec):
    headers=["Freq"]
    
    word_nonfreq={}
    
    for index in range(len(word_vec)):
        #word_nonfreq.append(word)
        
        for index2 in range(len(word_vec)):
            counter=0
            if index2+1 in range(len(word_vec)):
                print (word_vec[index],word_vec[index2+1])
                if word_vec[index]==word_vec[index2+1]:
                    counter+=1
        word_nonfreq[ word_vec[index]]=counter
        #print(counter)
        #df_frequencies.loc[word]=counter
    df_frequencies = pd.DataFrame(word_nonfreq,index=headers, columns=word_nonfreq ) 
    
    
    return df_frequencies


def count_freq(word_vec):
    headers=["Freq"]
    count = Counter(word_vec)
    df_frequencies = pd.DataFrame(count,index=headers, columns=count ) 
    #print(count)
    
    return df_frequencies
            
#ss=compute_freq(words)
xx=count_freq(words)
xx
#list(xx)
#ss
# Out:
#       theory  practice  science  Computer  discipline  spans
# Freq       1         1        1         1           1      1

# %% [markdown]
# ## Word Sense Disambiguation (WSD): LESK per Sentence
# Given an ambiguous word and the context in which the word occurs, Lesk returns a Synset with the highest number of overlapping words between the context sentence and different definitions from each Synset.

# %%
from nltk.wsd import lesk
'''
this function for compute lesk for each word(list of word) in sentence
'''
def lesk_words_sentence(words,sentence):
    lesks= []
    for word in words:
        if lesk(sentence,word, 'n') is not None:
            lesks.append(lesk(sentence,word, 'n'))
            #print("Word is: ",word,"\n LESK: ",lesk(sentence,word, 'n'),"\n Sentence: ",sentence )
        
    return lesks

# %%
'''
this function for compute lesk of word in sentence
'''

def lesk_word_sentence(word,sentence):
    #lesks= []
    #for word in words:
    lesk_synset=lesk(sentence,word, 'n')
        #print("Word is: ",word,"\n LESK: ",lesk(sentence,word, 'n'),"\n Sentence: ",sentence )
        
    return lesk_synset

# %%
lesks=lesk_words_sentence(words,setnences[0])
leskss=lesk_word_sentence(words[1],setnences[0])
#print(words[1],setnences[0])
#print (leskss)

# %%
#type(lesks)

# %% [markdown]
# ## Calculating WordNet Synset similarity using information content

# %%
from nltk.corpus import wordnet as wn
from nltk.corpus import wordnet_ic as wnic
from nltk.tokenize import word_tokenize

'''
this function for compute similarty between 2 synset 
'''

def similarity_by_infocontent(sense1, sense2, option):
    """ Returns similarity scores by information content. """
    #if sense1.pos != sense2.pos: # infocontent sim can't do diff POS.
        #return 0

    info_contents = ['ic-bnc-add1.dat', 'ic-bnc-resnik-add1.dat', 
                     'ic-bnc-resnik.dat', 'ic-bnc.dat', 

                     'ic-brown-add1.dat', 'ic-brown-resnik-add1.dat', 
                     'ic-brown-resnik.dat', 'ic-brown.dat', 

                     'ic-semcor-add1.dat', 'ic-semcor.dat',

                     'ic-semcorraw-add1.dat', 'ic-semcorraw-resnik-add1.dat', 
                     'ic-semcorraw-resnik.dat', 'ic-semcorraw.dat', 

                     'ic-shaks-add1.dat', 'ic-shaks-resnik.dat', 
                     'ic-shaks-resnink-add1.dat', 'ic-shaks.dat', 

                     'ic-treebank-add1.dat', 'ic-treebank-resnik-add1.dat', 
                     'ic-treebank-resnik.dat', 'ic-treebank.dat']

    if option in ['res', 'resnik']:
        #return wn.res_similarity(sense1, sense2, wnic.ic('ic-bnc-resnik-add1.dat'))
        #print('simRe snik (c1,c2) = -log p(lso(c1,c2)) = IC(lso(c1,c2)')
        return wn.res_similarity(sense1, sense2, wnic.ic('ic-treebank-resnik-add1.dat'))
    #return min(wn.res_similarity(sense1, sense2, wnic.ic(ic)) \
    #             for ic in info_contents)

    elif option in ['jcn', "jiang-conrath"]:
        #return wn.jcn_similarity(sense1, sense2, wnic.ic('ic-bnc-add1.dat'))
        #print('sim(jcn) (c1,c2 )= (IC(c1) + IC(c2 )) - 2IC(lso(c1,c2 ))')
        return wn.jcn_similarity(sense1, sense2, wnic.ic('ic-treebank.dat'))

    elif option in ['lin']:
        #return wn.lin_similarity(sense1, sense2, wnic.ic('ic-bnc-add1.dat'))
        #print('sim(lin) (c1,c2)=(2IC(lso(c1,c2 )))/(IC(c1)+IC(c2))')
        return wn.lin_similarity(sense1, sense2, wnic.ic('ic-treebank.dat'))

def sim(sense1, sense2, option="path"):
    """ Calculates similarity based on user's choice. """
    option = option.lower()
    if option.lower() in ["path", "path_similarity", 
                        "wup", "wupa", "wu-palmer", "wu-palmer",
                        'lch', "leacock-chordorow"]:
        return similarity_by_path(sense1, sense2, option) 
    elif option.lower() in ["res", "resnik",
                          "jcn","jiang-conrath",
                          "lin"]:
        return similarity_by_infocontent(sense1, sense2, option)

def max_similarity(context_sentence, ambiguous_word, option="path", 
                   pos=None, best=True):
    """
    Perform WSD by maximizing the sum of maximum similarity between possible 
    synsets of all words in the context sentence and the possible synsets of the 
    ambiguous words (see http://goo.gl/XMq2BI):
    {argmax}_{synset(a)}(\sum_{i}^{n}{{max}_{synset(i)}(sim(i,a))}
    """
    result = {}
    for i in wn.synsets(ambiguous_word):
        try:
            if pos and pos != str(i.pos()):
                continue
        except:
            if pos and pos != str(i.pos):
                continue
        result[i] = sum(max([sim(i,k,option) for k in wn.synsets(j)]+[0]) \
                        for j in word_tokenize(context_sentence))

    if option in ["res","resnik"]: # lower score = more similar
        result = sorted([(v,k) for k,v in result.items()])
    else: # higher score = more similar
        result = sorted([(v,k) for k,v in result.items()],reverse=True)
    #print (result)
    if best: return result[0][1];
    return result

# %%
print(lesks[2],lesks[1])
similarity_by_infocontent(lesks[2],lesks[1],'res')
# Out:
# Synset('discipline.n.02') Synset('science.n.01')
# 3.0862609105980248

# %%
#wn.res_similarity(lesks[1],lesks[2], wnic.ic('ic-bnc-resnik-add1.dat'))

# %%
#similarity_by_infocontent(lesks[2],lesks[1],'jcn')

# %%
#similarity_by_infocontent(lesks[2],lesks[1],'lin')

# %% [markdown]
# ## Simlarty per Words for Sentence

# %%
#df_sentence_similarty = pd.DataFrame(index=words, columns=words )
#df_sentence_similarty.loc[words[0]]=[1,2,3,4,5,6]
'''
to retrive similarty between list of synset
'''
rows_list = []
def simlarty_perWords(list_words,option):
    for index in range(len(list_words)):
        if index+1 <len(list_words):
            #df_similarty.loc[list_words[index]]
            #print(list_words[index].lowest_common_hypernyms(list_words[index+1]))
            #print(list_words[index],list_words[index+1],similarity_by_infocontent(list_words[index],list_words[index+1],option))
            rows_list.append(similarity_by_infocontent(list_words[index],list_words[index+1],option))
    return rows_list

# %%
simlarty_perWords(lesks,'res')
# Out:
# [-0.0,
#  3.0862609105980248,
#  0.622354726626253,
#  0.622354726626253,
#  1.7812696529610095]

# %%
#simlarty_perWords(lesks,'lin')

# %%
#simlarty_perWords(lesks,'jcn')

# %% [markdown]
# # TF-IDF
# TF-IDF stands for "Term Frequency, Inverse Document Frequency". It is a way to score the importance of words (or "terms") in a document based on how frequently they appear across multiple documents.
#
# Intuitively...
# If a word appears frequently in a document, it's important. Give the word a high score.
# But if a word appears in many documents, it's not a unique identifier. Give the word a low score.

# %%
import tfidf
#https://github.com/hrs/python-tf-idf
table = tfidf.tfidf()
table.addDocument("foo", [lesks[0],lesks[1],lesks[3]])
#table.addDocument("bar", ["alpha", "bravo", "charlie", "india", "juliet", "kilo"])
#table.addDocument("baz", ["kilo", "lima", "mike", "november"])

#print (table.similarities ([lesks[0],lesks[1],lesks[3]]))

# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
#df

# %% [markdown]
# # Pragraph Words Similarty

# %%
'''
calculate IC(p(C1)) per feature and 
'''
'''
get lesk of vector per pragraph
'''

def pragraph_lesks(pragraph,option):
    lesk_vec=[]# synset lesk of words per pragraph
    #synset_lesk_noDuplicates=[]
    Sentences=pragraph_to_setnences(pragraph)
    for sentence in Sentences:
        Words=remove_stopword_sentences(sentence)
        for word in Words:
            lesk_synset=lesk_word_sentence(word,sentence)
            if lesk_synset is not None:
                lesk_vec.append(lesk_synset)

    return lesk_vec

# %%
lesk_vec=pragraph_lesks(pragraphs[n_pragraph],'res')

# %%
'''
Cleaning vector per paragraph by the follow:
    Count Frequancy 
    Remove Nane values
    Remove Redundant 
    Dimensionality reduction based filter of lesk of vector per paragraph
    retrieve  Data frame contains remaining of lesk of vector per paragraph with frequencies
'''
def Dimensionality_reduction(lesk_vec):
    #Count Freq
    lesk_vec_before_reduction=count_freq(lesk_vec)
    sumd= lesk_vec_before_reduction.T.apply(np.sum)#np.sum(lesk_vec_before_reduction.ix['Freq':])
    lent=len(lesk_vec_before_reduction.T.index)
    avg=int (round(sumd/lent))
    #print(type(avg))
    #lesk_vec_after_freq=pd.DataFrame.dropna(lesk_vec_before_reduction[lesk_vec_before_reduction.ix['Freq':] > 1].T).T
    lesk_vec_after_freq=pd.DataFrame.dropna(lesk_vec_before_reduction[lesk_vec_before_reduction.ix['Freq':]/avg >1].T).T
    return lesk_vec_after_freq
    #total=df_freq.values.sum().sum()

# %%
lesk_vec_after_Dimensionality_reduction=Dimensionality_reduction(lesk_vec)
lesk_vec_after_Dimensionality_reduction
# Out:
#       Synset('information.n.05')  Synset('understanding.n.01')  \
# Freq                         3.0                           4.0
#
#       Synset('trouble.n.01')  Synset('software.n.01')  \
# Freq                     5.0                      5.0
#
#       Synset('discipline.n.02')  Synset('hardware.n.03')  \
# Freq                        9.0                      3.0
#
#       Synset('computer.n.01')  Synset('summons.n.03')  \
# Freq                     22.0                     4.0
#
#       Synset('particular.n.03')  Synset('science.n.01')  \
# Freq                        3.0                    19.0
#
#       Synset('design.n.06')  Synset('sphere.n.01')  Synset('scientist.n.01')  \
# Freq                    6.0                    4.0                       5.0
#
#       Synset('engineering.n.03')  Synset('terminus.n.03')
# Freq                         5.0                      3.0

# %%
'''
Cleaning vector per paragraph by the follow:
    Count Frequancy 
    Remove Nane values
    Remove Redundant 
    Dimensionality reduction based filter of lesk of vector per paragraph
    retrieve  Data frame contains remaining of lesk of vector per paragraph with frequencies and ratio
'''

def Dimensionality_reduction_with_ratio(lesk_vec):
    #Count Freq
    lesk_vec_before_reduction=count_freq(lesk_vec)
    sumd= lesk_vec_before_reduction.T.apply(np.sum)#np.sum(lesk_vec_before_reduction.ix['Freq':])
    lent=len(lesk_vec_before_reduction.T.index)
    avg=int (round(sumd/lent))
    
    lesk_vec_after_freq=pd.DataFrame.dropna(lesk_vec_before_reduction[lesk_vec_before_reduction.ix['Freq':]/avg > 1].T)
   
    total=lesk_vec_after_freq.values.sum().sum()
    #print(lesk_vec_after_freq.T)
    lesk_vec_after_freq['Ratio']=(lesk_vec_after_freq['Freq']/total)
    
    return lesk_vec_after_freq.T

# %%
rmv_red_ratio=Dimensionality_reduction_with_ratio(lesk_vec)
rmv_red_ratio
# Out:
#        Synset('information.n.05')  Synset('understanding.n.01')  \
# Freq                         3.00                          4.00
# Ratio                        0.03                          0.04
#
#        Synset('trouble.n.01')  Synset('software.n.01')  \
# Freq                     5.00                     5.00
# Ratio                    0.05                     0.05
#
#        Synset('discipline.n.02')  Synset('hardware.n.03')  \
# Freq                        9.00                     3.00
# Ratio                       0.09                     0.03
#
#        Synset('computer.n.01')  Synset('summons.n.03')  \
# Freq                     22.00                    4.00
# Ratio                     0.22                    0.04
#
#        Synset('particular.n.03')  Synset('science.n.01')  \
# Freq                        3.00                   19.00
# Ratio                       0.03                    0.19
#
#        Synset('design.n.06')  Synset('sphere.n.01')  Synset('scientist.n.01')  \
# Freq                    6.00                   4.00                      5.00
# Ratio                   0.06                   0.04                      0.05
#
#        Synset('engineering.n.03')  Synset('terminus.n.03')
# Freq                         5.00                     3.00
# Ratio                        0.05                     0.03

# %%
'''
calculate simantic simelart for Dimensionality reduction vector
say vector is n element [n1,n2,n3,.....nm], data frame row=n,col=n
sim(n[row],n[col])if if row != col:
option is sim method like res,lin,jcn ...... for IC

'''


def sim_pragraph_lesk(df_freq,option):
    
    series=list(df_freq)#pd.Series(data=lesk_vec)
    #series.drop_duplicates()
    synset_lesk_noDuplicates= series#.tolist()    
    df_all_synset_lesk = pd.DataFrame(index=series, columns=series )            
    #print ("synset_lesk_noDuplicates",len(synset_lesk_noDuplicates))
    
    for row in range(len(synset_lesk_noDuplicates)):
        try:
            data_row=[]
            for col in range(len(synset_lesk_noDuplicates)):

                    if row < col:

                        sim=similarity_by_infocontent(series[row],series[col],option)
                        if sim is not None:
                            data_row.append(sim)
                        else:
                            data_row.append(0)
                        #print(len(data_row))


                    else:

                        data_row.append(0)
                        #print(len(data_row))

            #print(series[row])
            df_all_synset_lesk.loc[series[row]]=data_row
        except  Exception as inst:
                data_row.append(0)
                print(type(inst))    # the exception instance
                print(inst.args)     # arguments stored in .args
                print(inst)          # __str__ allows args to be printed directly,
                pass
                #print("Ex")
    return df_all_synset_lesk

# %%
sim_lesk_vec_after_Dimensionality_reduction=sim_pragraph_lesk(lesk_vec_after_Dimensionality_reduction,'res')
sim_lesk_vec_after_Dimensionality_reduction
# Out:
#                              Synset('information.n.05')  \
# Synset('information.n.05')                            0
# Synset('understanding.n.01')                          0
# Synset('trouble.n.01')                                0
# Synset('software.n.01')                               0
# Synset('discipline.n.02')                             0
# Synset('hardware.n.03')                               0
# Synset('computer.n.01')                               0
# Synset('summons.n.03')                                0
# Synset('particular.n.03')                             0
# Synset('science.n.01')                                0
# Synset('design.n.06')                                 0
# Synset('sphere.n.01')                                 0
# Synset('scientist.n.01')                              0
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
#
#                              Synset('understanding.n.01')  \
# Synset('information.n.05')                       0.622355
# Synset('understanding.n.01')                            0
# Synset('trouble.n.01')                                  0
# Synset('software.n.01')                                 0
# Synset('discipline.n.02')                               0
# Synset('hardware.n.03')                                 0
# Synset('computer.n.01')                                 0
# Synset('summons.n.03')                                  0
# Synset('particular.n.03')                               0
# Synset('science.n.01')                                  0
# Synset('design.n.06')                                   0
# Synset('sphere.n.01')                                   0
# Synset('scientist.n.01')                                0
# Synset('engineering.n.03')                              0
# Synset('terminus.n.03')                                 0
#
#                              Synset('trouble.n.01') Synset('software.n.01')  \
# Synset('information.n.05')                 0.622355                0.622355
# Synset('understanding.n.01')                3.08626                0.622355
# Synset('trouble.n.01')                            0                0.622355
# Synset('software.n.01')                           0                       0
# Synset('discipline.n.02')                         0                       0
# Synset('hardware.n.03')                           0                       0
# Synset('computer.n.01')                           0                       0
# Synset('summons.n.03')                            0                       0
# Synset('particular.n.03')                         0                       0
# Synset('science.n.01')                            0                       0
# Synset('design.n.06')                             0                       0
# Synset('sphere.n.01')                             0                       0
# Synset('scientist.n.01')                          0                       0
# Synset('engineering.n.03')                        0                       0
# Synset('terminus.n.03')                           0                       0
#
#                              Synset('discipline.n.02')  \
# Synset('information.n.05')                    0.622355
# Synset('understanding.n.01')                   3.08626
# Synset('trouble.n.01')                         3.08626
# Synset('software.n.01')                       0.622355
# Synset('discipline.n.02')                            0
# Synset('hardware.n.03')                              0
# Synset('computer.n.01')                              0
# Synset('summons.n.03')                               0
# Synset('particular.n.03')                            0
# Synset('science.n.01')                               0
# Synset('design.n.06')                                0
# Synset('sphere.n.01')                                0
# Synset('scientist.n.01')                             0
# Synset('engineering.n.03')                           0
# Synset('terminus.n.03')                              0
#
#                              Synset('hardware.n.03') Synset('computer.n.01')  \
# Synset('information.n.05')                        -0                      -0
# Synset('understanding.n.01')                      -0                      -0
# Synset('trouble.n.01')                            -0                      -0
# Synset('software.n.01')                           -0                      -0
# Synset('discipline.n.02')                         -0                      -0
# Synset('hardware.n.03')                            0                 1.27313
# Synset('computer.n.01')                            0                       0
# Synset('summons.n.03')                             0                       0
# Synset('particular.n.03')                          0                       0
# Synset('science.n.01')                             0                       0
# Synset('design.n.06')                              0                       0
# Synset('sphere.n.01')                              0                       0
# Synset('scientist.n.01')                           0                       0
# Synset('engineering.n.03')                         0                       0
# Synset('terminus.n.03')                            0                       0
#
#                              Synset('summons.n.03') Synset('particular.n.03')  \
# Synset('information.n.05')                 0.622355                  0.622355
# Synset('understanding.n.01')               0.622355                  0.622355
# Synset('trouble.n.01')                     0.622355                  0.622355
# Synset('software.n.01')                     4.20093                   2.88435
# Synset('discipline.n.02')                  0.622355                  0.622355
# Synset('hardware.n.03')                          -0                        -0
# Synset('computer.n.01')                          -0                        -0
# Synset('summons.n.03')                            0                   2.88435
# Synset('particular.n.03')                         0                         0
# Synset('science.n.01')                            0                         0
# Synset('design.n.06')                             0                         0
# Synset('sphere.n.01')                             0                         0
# Synset('scientist.n.01')                          0                         0
# Synset('engineering.n.03')                        0                         0
# Synset('terminus.n.03')                           0                         0
#
#                              Synset('science.n.01') Synset('design.n.06')  \
# Synset('information.n.05')                 0.622355                    -0
# Synset('understanding.n.01')                3.08626                    -0
# Synset('trouble.n.01')                      3.08626                    -0
# Synset('software.n.01')                    0.622355                    -0
# Synset('discipline.n.02')                   3.08626                    -0
# Synset('hardware.n.03')                          -0               1.27313
# Synset('computer.n.01')                          -0               2.56104
# Synset('summons.n.03')                     0.622355                    -0
# Synset('particular.n.03')                  0.622355                    -0
# Synset('science.n.01')                            0                    -0
# Synset('design.n.06')                             0                     0
# Synset('sphere.n.01')                             0                     0
# Synset('scientist.n.01')                          0                     0
# Synset('engineering.n.03')                        0                     0
# Synset('terminus.n.03')                           0                     0
#
#                              Synset('sphere.n.01') Synset('scientist.n.01')  \
# Synset('information.n.05')                0.622355                       -0
# Synset('understanding.n.01')              0.622355                       -0
# Synset('trouble.n.01')                    0.622355                       -0
# Synset('software.n.01')                   0.622355                       -0
# Synset('discipline.n.02')                 0.622355                       -0
# Synset('hardware.n.03')                         -0                  1.27313
# Synset('computer.n.01')                         -0                  1.55201
# Synset('summons.n.03')                    0.622355                       -0
# Synset('particular.n.03')                 0.622355                       -0
# Synset('science.n.01')                    0.622355                       -0
# Synset('design.n.06')                           -0                  1.55201
# Synset('sphere.n.01')                            0                       -0
# Synset('scientist.n.01')                         0                        0
# Synset('engineering.n.03')                       0                        0
# Synset('terminus.n.03')                          0                        0
#
#                              Synset('engineering.n.03')  \
# Synset('information.n.05')                           -0
# Synset('understanding.n.01')                         -0
# Synset('trouble.n.01')                               -0
# Synset('software.n.01')                              -0
# Synset('discipline.n.02')                            -0
# Synset('hardware.n.03')                         1.27313
# Synset('computer.n.01')                         2.56104
# Synset('summons.n.03')                               -0
# Synset('particular.n.03')                            -0
# Synset('science.n.01')                               -0
# Synset('design.n.06')                           2.56104
# Synset('sphere.n.01')                                -0
# Synset('scientist.n.01')                        1.55201
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
#
#                              Synset('terminus.n.03')
# Synset('information.n.05')                  0.622355
# Synset('understanding.n.01')                0.622355
# Synset('trouble.n.01')                      0.622355
# Synset('software.n.01')                     0.622355
# Synset('discipline.n.02')                   0.622355
# Synset('hardware.n.03')                      1.27313
# Synset('computer.n.01')                      2.56104
# Synset('summons.n.03')                      0.622355
# Synset('particular.n.03')                   0.622355
# Synset('science.n.01')                      0.622355
# Synset('design.n.06')                        4.91124
# Synset('sphere.n.01')                         2.5661
# Synset('scientist.n.01')                     1.55201
# Synset('engineering.n.03')                   2.56104
# Synset('terminus.n.03')                            0

# %%
'''
calculate similartyin_pragraph

'''

def similarty_pragraph(pragraph,option):
    lesk_vec=pragraph_lesks(pragraph,option)
    lesk_vec_after_Dimensionality_reduction=Dimensionality_reduction(lesk_vec)
    sim_lesk_vec_after_Dimensionality_reduction=sim_pragraph_lesk(lesk_vec_after_Dimensionality_reduction,option)
    return sim_lesk_vec_after_Dimensionality_reduction

# %%
res_df=similarty_pragraph(pragraphs[n_pragraph],'res')
res_df
#res_df.to_csv('res_df.csv')
# Out:
#                              Synset('information.n.05')  \
# Synset('information.n.05')                            0
# Synset('understanding.n.01')                          0
# Synset('trouble.n.01')                                0
# Synset('software.n.01')                               0
# Synset('discipline.n.02')                             0
# Synset('hardware.n.03')                               0
# Synset('computer.n.01')                               0
# Synset('summons.n.03')                                0
# Synset('particular.n.03')                             0
# Synset('science.n.01')                                0
# Synset('design.n.06')                                 0
# Synset('sphere.n.01')                                 0
# Synset('scientist.n.01')                              0
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
#
#                              Synset('understanding.n.01')  \
# Synset('information.n.05')                       0.622355
# Synset('understanding.n.01')                            0
# Synset('trouble.n.01')                                  0
# Synset('software.n.01')                                 0
# Synset('discipline.n.02')                               0
# Synset('hardware.n.03')                                 0
# Synset('computer.n.01')                                 0
# Synset('summons.n.03')                                  0
# Synset('particular.n.03')                               0
# Synset('science.n.01')                                  0
# Synset('design.n.06')                                   0
# Synset('sphere.n.01')                                   0
# Synset('scientist.n.01')                                0
# Synset('engineering.n.03')                              0
# Synset('terminus.n.03')                                 0
#
#                              Synset('trouble.n.01') Synset('software.n.01')  \
# Synset('information.n.05')                 0.622355                0.622355
# Synset('understanding.n.01')                3.08626                0.622355
# Synset('trouble.n.01')                            0                0.622355
# Synset('software.n.01')                           0                       0
# Synset('discipline.n.02')                         0                       0
# Synset('hardware.n.03')                           0                       0
# Synset('computer.n.01')                           0                       0
# Synset('summons.n.03')                            0                       0
# Synset('particular.n.03')                         0                       0
# Synset('science.n.01')                            0                       0
# Synset('design.n.06')                             0                       0
# Synset('sphere.n.01')                             0                       0
# Synset('scientist.n.01')                          0                       0
# Synset('engineering.n.03')                        0                       0
# Synset('terminus.n.03')                           0                       0
#
#                              Synset('discipline.n.02')  \
# Synset('information.n.05')                    0.622355
# Synset('understanding.n.01')                   3.08626
# Synset('trouble.n.01')                         3.08626
# Synset('software.n.01')                       0.622355
# Synset('discipline.n.02')                            0
# Synset('hardware.n.03')                              0
# Synset('computer.n.01')                              0
# Synset('summons.n.03')                               0
# Synset('particular.n.03')                            0
# Synset('science.n.01')                               0
# Synset('design.n.06')                                0
# Synset('sphere.n.01')                                0
# Synset('scientist.n.01')                             0
# Synset('engineering.n.03')                           0
# Synset('terminus.n.03')                              0
#
#                              Synset('hardware.n.03') Synset('computer.n.01')  \
# Synset('information.n.05')                        -0                      -0
# Synset('understanding.n.01')                      -0                      -0
# Synset('trouble.n.01')                            -0                      -0
# Synset('software.n.01')                           -0                      -0
# Synset('discipline.n.02')                         -0                      -0
# Synset('hardware.n.03')                            0                 1.27313
# Synset('computer.n.01')                            0                       0
# Synset('summons.n.03')                             0                       0
# Synset('particular.n.03')                          0                       0
# Synset('science.n.01')                             0                       0
# Synset('design.n.06')                              0                       0
# Synset('sphere.n.01')                              0                       0
# Synset('scientist.n.01')                           0                       0
# Synset('engineering.n.03')                         0                       0
# Synset('terminus.n.03')                            0                       0
#
#                              Synset('summons.n.03') Synset('particular.n.03')  \
# Synset('information.n.05')                 0.622355                  0.622355
# Synset('understanding.n.01')               0.622355                  0.622355
# Synset('trouble.n.01')                     0.622355                  0.622355
# Synset('software.n.01')                     4.20093                   2.88435
# Synset('discipline.n.02')                  0.622355                  0.622355
# Synset('hardware.n.03')                          -0                        -0
# Synset('computer.n.01')                          -0                        -0
# Synset('summons.n.03')                            0                   2.88435
# Synset('particular.n.03')                         0                         0
# Synset('science.n.01')                            0                         0
# Synset('design.n.06')                             0                         0
# Synset('sphere.n.01')                             0                         0
# Synset('scientist.n.01')                          0                         0
# Synset('engineering.n.03')                        0                         0
# Synset('terminus.n.03')                           0                         0
#
#                              Synset('science.n.01') Synset('design.n.06')  \
# Synset('information.n.05')                 0.622355                    -0
# Synset('understanding.n.01')                3.08626                    -0
# Synset('trouble.n.01')                      3.08626                    -0
# Synset('software.n.01')                    0.622355                    -0
# Synset('discipline.n.02')                   3.08626                    -0
# Synset('hardware.n.03')                          -0               1.27313
# Synset('computer.n.01')                          -0               2.56104
# Synset('summons.n.03')                     0.622355                    -0
# Synset('particular.n.03')                  0.622355                    -0
# Synset('science.n.01')                            0                    -0
# Synset('design.n.06')                             0                     0
# Synset('sphere.n.01')                             0                     0
# Synset('scientist.n.01')                          0                     0
# Synset('engineering.n.03')                        0                     0
# Synset('terminus.n.03')                           0                     0
#
#                              Synset('sphere.n.01') Synset('scientist.n.01')  \
# Synset('information.n.05')                0.622355                       -0
# Synset('understanding.n.01')              0.622355                       -0
# Synset('trouble.n.01')                    0.622355                       -0
# Synset('software.n.01')                   0.622355                       -0
# Synset('discipline.n.02')                 0.622355                       -0
# Synset('hardware.n.03')                         -0                  1.27313
# Synset('computer.n.01')                         -0                  1.55201
# Synset('summons.n.03')                    0.622355                       -0
# Synset('particular.n.03')                 0.622355                       -0
# Synset('science.n.01')                    0.622355                       -0
# Synset('design.n.06')                           -0                  1.55201
# Synset('sphere.n.01')                            0                       -0
# Synset('scientist.n.01')                         0                        0
# Synset('engineering.n.03')                       0                        0
# Synset('terminus.n.03')                          0                        0
#
#                              Synset('engineering.n.03')  \
# Synset('information.n.05')                           -0
# Synset('understanding.n.01')                         -0
# Synset('trouble.n.01')                               -0
# Synset('software.n.01')                              -0
# Synset('discipline.n.02')                            -0
# Synset('hardware.n.03')                         1.27313
# Synset('computer.n.01')                         2.56104
# Synset('summons.n.03')                               -0
# Synset('particular.n.03')                            -0
# Synset('science.n.01')                               -0
# Synset('design.n.06')                           2.56104
# Synset('sphere.n.01')                                -0
# Synset('scientist.n.01')                        1.55201
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
#
#                              Synset('terminus.n.03')
# Synset('information.n.05')                  0.622355
# Synset('understanding.n.01')                0.622355
# Synset('trouble.n.01')                      0.622355
# Synset('software.n.01')                     0.622355
# Synset('discipline.n.02')                   0.622355
# Synset('hardware.n.03')                      1.27313
# Synset('computer.n.01')                      2.56104
# Synset('summons.n.03')                      0.622355
# Synset('particular.n.03')                   0.622355
# Synset('science.n.01')                      0.622355
# Synset('design.n.06')                        4.91124
# Synset('sphere.n.01')                         2.5661
# Synset('scientist.n.01')                     1.55201
# Synset('engineering.n.03')                   2.56104
# Synset('terminus.n.03')                            0

# %%
jcn_df=similarty_pragraph(pragraphs[n_pragraph],'jcn')
jcn_df
# Out:
#                              Synset('information.n.05')  \
# Synset('information.n.05')                            0
# Synset('understanding.n.01')                          0
# Synset('trouble.n.01')                                0
# Synset('software.n.01')                               0
# Synset('discipline.n.02')                             0
# Synset('hardware.n.03')                               0
# Synset('computer.n.01')                               0
# Synset('summons.n.03')                                0
# Synset('particular.n.03')                             0
# Synset('science.n.01')                                0
# Synset('design.n.06')                                 0
# Synset('sphere.n.01')                                 0
# Synset('scientist.n.01')                              0
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
#
#                              Synset('understanding.n.01')  \
# Synset('information.n.05')                      0.0623568
# Synset('understanding.n.01')                            0
# Synset('trouble.n.01')                                  0
# Synset('software.n.01')                                 0
# Synset('discipline.n.02')                               0
# Synset('hardware.n.03')                                 0
# Synset('computer.n.01')                                 0
# Synset('summons.n.03')                                  0
# Synset('particular.n.03')                               0
# Synset('science.n.01')                                  0
# Synset('design.n.06')                                   0
# Synset('sphere.n.01')                                   0
# Synset('scientist.n.01')                                0
# Synset('engineering.n.03')                              0
# Synset('terminus.n.03')                                 0
#
#                              Synset('trouble.n.01') Synset('software.n.01')  \
# Synset('information.n.05')                0.0630506               0.0657508
# Synset('understanding.n.01')               0.101266               0.0712561
# Synset('trouble.n.01')                            0               0.0721635
# Synset('software.n.01')                           0                       0
# Synset('discipline.n.02')                         0                       0
# Synset('hardware.n.03')                           0                       0
# Synset('computer.n.01')                           0                       0
# Synset('summons.n.03')                            0                       0
# Synset('particular.n.03')                         0                       0
# Synset('science.n.01')                            0                       0
# Synset('design.n.06')                             0                       0
# Synset('sphere.n.01')                             0                       0
# Synset('scientist.n.01')                          0                       0
# Synset('engineering.n.03')                        0                       0
# Synset('terminus.n.03')                           0                       0
#
#                              Synset('discipline.n.02')  \
# Synset('information.n.05')                   0.0516642
# Synset('understanding.n.01')                 0.0747919
# Synset('trouble.n.01')                       0.0757923
# Synset('software.n.01')                      0.0576272
# Synset('discipline.n.02')                            0
# Synset('hardware.n.03')                              0
# Synset('computer.n.01')                              0
# Synset('summons.n.03')                               0
# Synset('particular.n.03')                            0
# Synset('science.n.01')                               0
# Synset('design.n.06')                                0
# Synset('sphere.n.01')                                0
# Synset('scientist.n.01')                             0
# Synset('engineering.n.03')                           0
# Synset('terminus.n.03')                              0
#
#                              Synset('hardware.n.03') Synset('computer.n.01')  \
# Synset('information.n.05')                 0.0572731               0.0607247
# Synset('understanding.n.01')               0.0614056               0.0653906
# Synset('trouble.n.01')                     0.0620783                0.066154
# Synset('software.n.01')                    0.0646942               0.0691328
# Synset('discipline.n.02')                  0.0510095               0.0537295
# Synset('hardware.n.03')                            0               0.0774187
# Synset('computer.n.01')                            0                       0
# Synset('summons.n.03')                             0                       0
# Synset('particular.n.03')                          0                       0
# Synset('science.n.01')                             0                       0
# Synset('design.n.06')                              0                       0
# Synset('sphere.n.01')                              0                       0
# Synset('scientist.n.01')                           0                       0
# Synset('engineering.n.03')                         0                       0
# Synset('terminus.n.03')                            0                       0
#
#                              Synset('summons.n.03') Synset('particular.n.03')  \
# Synset('information.n.05')                0.0579792                 0.0533344
# Synset('understanding.n.01')               0.062218                 0.0569003
# Synset('trouble.n.01')                    0.0629087                 0.0574775
# Synset('software.n.01')                    0.116376                 0.0795565
# Synset('discipline.n.02')                 0.0515688                 0.0478615
# Synset('hardware.n.03')                    0.057156                  0.052637
# Synset('computer.n.01')                    0.060593                 0.0555383
# Synset('summons.n.03')                            0                 0.0684541
# Synset('particular.n.03')                         0                         0
# Synset('science.n.01')                            0                         0
# Synset('design.n.06')                             0                         0
# Synset('sphere.n.01')                             0                         0
# Synset('scientist.n.01')                          0                         0
# Synset('engineering.n.03')                        0                         0
# Synset('terminus.n.03')                           0                         0
#
#                              Synset('science.n.01') Synset('design.n.06')  \
# Synset('information.n.05')                0.0660729             0.0521985
# Synset('understanding.n.01')               0.109296             0.0556093
# Synset('trouble.n.01')                     0.111446             0.0561604
# Synset('software.n.01')                   0.0761502             0.0582927
# Synset('discipline.n.02')                 0.0802023             0.0469448
# Synset('hardware.n.03')                    0.065006             0.0640752
# Synset('computer.n.01')                    0.069489             0.0789185
# Synset('summons.n.03')                    0.0659171             0.0521011
# Synset('particular.n.03')                 0.0599785             0.0483197
# Synset('science.n.01')                            0             0.0585458
# Synset('design.n.06')                             0                     0
# Synset('sphere.n.01')                             0                     0
# Synset('scientist.n.01')                          0                     0
# Synset('engineering.n.03')                        0                     0
# Synset('terminus.n.03')                           0                     0
#
#                              Synset('sphere.n.01') Synset('scientist.n.01')  \
# Synset('information.n.05')               0.0628367                0.0660541
# Synset('understanding.n.01')             0.0678461                0.0716124
# Synset('trouble.n.01')                   0.0686683                 0.072529
# Synset('software.n.01')                  0.0718834                0.0761252
# Synset('discipline.n.02')                0.0553763                  0.05786
# Synset('hardware.n.03')                  0.0618709                0.0862953
# Synset('computer.n.01')                  0.0659185                0.0990353
# Synset('summons.n.03')                   0.0626957                0.0658983
# Synset('particular.n.03')                0.0572996                 0.059963
# Synset('science.n.01')                   0.0722685                0.0765573
# Synset('design.n.06')                    0.0559906                0.0782026
# Synset('sphere.n.01')                            0                 0.072246
# Synset('scientist.n.01')                         0                        0
# Synset('engineering.n.03')                       0                        0
# Synset('terminus.n.03')                          0                        0
#
#                              Synset('engineering.n.03')  \
# Synset('information.n.05')                    0.0514613
# Synset('understanding.n.01')                  0.0547734
# Synset('trouble.n.01')                         0.055308
# Synset('software.n.01')                       0.0573749
# Synset('discipline.n.02')                     0.0463477
# Synset('hardware.n.03')                        0.062968
# Synset('computer.n.01')                       0.0772455
# Synset('summons.n.03')                        0.0513667
# Synset('particular.n.03')                     0.0476873
# Synset('science.n.01')                          0.05762
# Synset('design.n.06')                         0.0639565
# Synset('sphere.n.01')                         0.0551433
# Synset('scientist.n.01')                      0.0765595
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
#
#                              Synset('terminus.n.03')
# Synset('information.n.05')                  0.062071
# Synset('understanding.n.01')               0.0669544
# Synset('trouble.n.01')                      0.067755
# Synset('software.n.01')                    0.0708832
# Synset('discipline.n.02')                  0.0547809
# Synset('hardware.n.03')                    0.0737168
# Synset('computer.n.01')                    0.0940726
# Synset('summons.n.03')                     0.0619335
# Synset('particular.n.03')                  0.0566623
# Synset('science.n.01')                     0.0712577
# Synset('design.n.06')                       0.114371
# Synset('sphere.n.01')                      0.0909789
# Synset('scientist.n.01')                   0.0930573
# Synset('engineering.n.03')                 0.0735597
# Synset('terminus.n.03')                            0

# %%
lin_df=similarty_pragraph(pragraphs[n_pragraph],'lin')
lin_df
# Out:
#                              Synset('information.n.05')  \
# Synset('information.n.05')                            0
# Synset('understanding.n.01')                          0
# Synset('trouble.n.01')                                0
# Synset('software.n.01')                               0
# Synset('discipline.n.02')                             0
# Synset('hardware.n.03')                               0
# Synset('computer.n.01')                               0
# Synset('summons.n.03')                                0
# Synset('particular.n.03')                             0
# Synset('science.n.01')                                0
# Synset('design.n.06')                                 0
# Synset('sphere.n.01')                                 0
# Synset('scientist.n.01')                              0
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
#
#                              Synset('understanding.n.01')  \
# Synset('information.n.05')                      0.0590201
# Synset('understanding.n.01')                            0
# Synset('trouble.n.01')                                  0
# Synset('software.n.01')                                 0
# Synset('discipline.n.02')                               0
# Synset('hardware.n.03')                                 0
# Synset('computer.n.01')                                 0
# Synset('summons.n.03')                                  0
# Synset('particular.n.03')                               0
# Synset('science.n.01')                                  0
# Synset('design.n.06')                                   0
# Synset('sphere.n.01')                                   0
# Synset('scientist.n.01')                                0
# Synset('engineering.n.03')                              0
# Synset('terminus.n.03')                                 0
#
#                              Synset('trouble.n.01') Synset('software.n.01')  \
# Synset('information.n.05')                0.0596377               0.0620333
# Synset('understanding.n.01')               0.370666               0.0668799
# Synset('trouble.n.01')                            0               0.0676739
# Synset('software.n.01')                           0                       0
# Synset('discipline.n.02')                         0                       0
# Synset('hardware.n.03')                           0                       0
# Synset('computer.n.01')                           0                       0
# Synset('summons.n.03')                            0                       0
# Synset('particular.n.03')                         0                       0
# Synset('science.n.01')                            0                       0
# Synset('design.n.06')                             0                       0
# Synset('sphere.n.01')                             0                       0
# Synset('scientist.n.01')                          0                       0
# Synset('engineering.n.03')                        0                       0
# Synset('terminus.n.03')                           0                       0
#
#                              Synset('discipline.n.02')  \
# Synset('information.n.05')                   0.0493996
# Synset('understanding.n.01')                  0.303136
# Synset('trouble.n.01')                         0.30595
# Synset('software.n.01')                      0.0547889
# Synset('discipline.n.02')                            0
# Synset('hardware.n.03')                              0
# Synset('computer.n.01')                              0
# Synset('summons.n.03')                               0
# Synset('particular.n.03')                            0
# Synset('science.n.01')                               0
# Synset('design.n.06')                                0
# Synset('sphere.n.01')                                0
# Synset('scientist.n.01')                             0
# Synset('engineering.n.03')                           0
# Synset('terminus.n.03')                              0
#
#                              Synset('hardware.n.03') Synset('computer.n.01')  \
# Synset('information.n.05')                        -0                      -0
# Synset('understanding.n.01')                      -0                      -0
# Synset('trouble.n.01')                            -0                      -0
# Synset('software.n.01')                           -0                      -0
# Synset('discipline.n.02')                         -0                      -0
# Synset('hardware.n.03')                            0                0.177816
# Synset('computer.n.01')                            0                       0
# Synset('summons.n.03')                             0                       0
# Synset('particular.n.03')                          0                       0
# Synset('science.n.01')                             0                       0
# Synset('design.n.06')                              0                       0
# Synset('sphere.n.01')                              0                       0
# Synset('scientist.n.01')                           0                       0
# Synset('engineering.n.03')                         0                       0
# Synset('terminus.n.03')                            0                       0
#
#                              Synset('summons.n.03') Synset('particular.n.03')  \
# Synset('information.n.05')                 0.055105                 0.0509153
# Synset('understanding.n.01')              0.0588964                 0.0541352
# Synset('trouble.n.01')                    0.0595114                 0.0546543
# Synset('software.n.01')                    0.471227                  0.291954
# Synset('discipline.n.02')                 0.0493129                 0.0459306
# Synset('hardware.n.03')                          -0                        -0
# Synset('computer.n.01')                          -0                        -0
# Synset('summons.n.03')                            0                   0.26188
# Synset('particular.n.03')                         0                         0
# Synset('science.n.01')                            0                         0
# Synset('design.n.06')                             0                         0
# Synset('sphere.n.01')                             0                         0
# Synset('scientist.n.01')                          0                         0
# Synset('engineering.n.03')                        0                         0
# Synset('terminus.n.03')                           0                         0
#
#                              Synset('science.n.01') Synset('design.n.06')  \
# Synset('information.n.05')                0.0623182                    -0
# Synset('understanding.n.01')               0.388634                    -0
# Synset('trouble.n.01')                     0.393272                    -0
# Synset('software.n.01')                   0.0711466                    -0
# Synset('discipline.n.02')                  0.318089                    -0
# Synset('hardware.n.03')                          -0              0.151822
# Synset('computer.n.01')                          -0              0.272089
# Synset('summons.n.03')                    0.0621803                    -0
# Synset('particular.n.03')                 0.0568972                    -0
# Synset('science.n.01')                            0                    -0
# Synset('design.n.06')                             0                     0
# Synset('sphere.n.01')                             0                     0
# Synset('scientist.n.01')                          0                     0
# Synset('engineering.n.03')                        0                     0
# Synset('terminus.n.03')                           0                     0
#
#                              Synset('sphere.n.01') Synset('scientist.n.01')  \
# Synset('information.n.05')               0.0594473                       -0
# Synset('understanding.n.01')             0.0638838                       -0
# Synset('trouble.n.01')                   0.0646079                       -0
# Synset('software.n.01')                  0.0674289                       -0
# Synset('discipline.n.02')                0.0527618                       -0
# Synset('hardware.n.03')                         -0                 0.194244
# Synset('computer.n.01')                         -0                 0.245856
# Synset('summons.n.03')                   0.0593218                       -0
# Synset('particular.n.03')                0.0544944                       -0
# Synset('science.n.01')                   0.0677657                       -0
# Synset('design.n.06')                           -0                 0.204726
# Synset('sphere.n.01')                            0                       -0
# Synset('scientist.n.01')                         0                        0
# Synset('engineering.n.03')                       0                        0
# Synset('terminus.n.03')                          0                        0
#
#                              Synset('engineering.n.03')  \
# Synset('information.n.05')                           -0
# Synset('understanding.n.01')                         -0
# Synset('trouble.n.01')                               -0
# Synset('software.n.01')                              -0
# Synset('discipline.n.02')                            -0
# Synset('hardware.n.03')                        0.149591
# Synset('computer.n.01')                        0.267866
# Synset('summons.n.03')                               -0
# Synset('particular.n.03')                            -0
# Synset('science.n.01')                               -0
# Synset('design.n.06')                          0.232498
# Synset('sphere.n.01')                                -0
# Synset('scientist.n.01')                       0.201291
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
#
#                              Synset('terminus.n.03')
# Synset('information.n.05')                 0.0587655
# Synset('understanding.n.01')               0.0630972
# Synset('trouble.n.01')                     0.0638035
# Synset('software.n.01')                    0.0665532
# Synset('discipline.n.02')                   0.052224
# Synset('hardware.n.03')                     0.170765
# Synset('computer.n.01')                     0.308232
# Synset('summons.n.03')                     0.0586429
# Synset('particular.n.03')                   0.053921
# Synset('science.n.01')                     0.0668813
# Synset('design.n.06')                       0.515769
# Synset('sphere.n.01')                       0.305163
# Synset('scientist.n.01')                    0.234495
# Synset('engineering.n.03')                  0.258387
# Synset('terminus.n.03')                            0

# %% [markdown]
# # Classfication per pragraph

# %%
'''
to calculate mean per colum and ratio of this mean for any matrix 
'''

def add_mean_ratio(df):
    inverse_df=df.T

    #inverse_df['Mean']=inverse_df.apply(np.mean)
    inverse_df['Mean']=inverse_df.mean(axis=1)
    total=inverse_df.values.sum()

    #ss['Max']=ss.apply(np.max)
    #ss['MIN']=ss.apply(np.min)
    #ss['Total']=ss.apply(np.sum) #[col,row] #.apply(np.mean)
    #ss.groupby("Mean").sum()
    total_mean=inverse_df['Mean'].sum()

    inverse_df['Ratio_mean']=inverse_df['Mean']/total_mean#ss.apply(np.mean)
    #ss['RATIO']=ss.apply(ss['Mean']/ss['Total'])
    return inverse_df.T

# %%
#inverse_df=res_df.T
#inverse_df['Mean']=inverse_df.mean(axis=1)
#inverse_df.T

mres_df=add_mean_ratio(res_df)
mres_df
# Out:
#                              Synset('information.n.05')  \
# Synset('information.n.05')                            0
# Synset('understanding.n.01')                          0
# Synset('trouble.n.01')                                0
# Synset('software.n.01')                               0
# Synset('discipline.n.02')                             0
# Synset('hardware.n.03')                               0
# Synset('computer.n.01')                               0
# Synset('summons.n.03')                                0
# Synset('particular.n.03')                             0
# Synset('science.n.01')                                0
# Synset('design.n.06')                                 0
# Synset('sphere.n.01')                                 0
# Synset('scientist.n.01')                              0
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
# Mean                                                  0
# Ratio_mean                                            0
#
#                              Synset('understanding.n.01')  \
# Synset('information.n.05')                       0.622355
# Synset('understanding.n.01')                            0
# Synset('trouble.n.01')                                  0
# Synset('software.n.01')                                 0
# Synset('discipline.n.02')                               0
# Synset('hardware.n.03')                                 0
# Synset('computer.n.01')                                 0
# Synset('summons.n.03')                                  0
# Synset('particular.n.03')                               0
# Synset('science.n.01')                                  0
# Synset('design.n.06')                                   0
# Synset('sphere.n.01')                                   0
# Synset('scientist.n.01')                                0
# Synset('engineering.n.03')                              0
# Synset('terminus.n.03')                                 0
# Mean                                            0.0414903
# Ratio_mean                                     0.00748689
#
#                              Synset('trouble.n.01') Synset('software.n.01')  \
# Synset('information.n.05')                 0.622355                0.622355
# Synset('understanding.n.01')                3.08626                0.622355
# Synset('trouble.n.01')                            0                0.622355
# Synset('software.n.01')                           0                       0
# Synset('discipline.n.02')                         0                       0
# Synset('hardware.n.03')                           0                       0
# Synset('computer.n.01')                           0                       0
# Synset('summons.n.03')                            0                       0
# Synset('particular.n.03')                         0                       0
# Synset('science.n.01')                            0                       0
# Synset('design.n.06')                             0                       0
# Synset('sphere.n.01')                             0                       0
# Synset('scientist.n.01')                          0                       0
# Synset('engineering.n.03')                        0                       0
# Synset('terminus.n.03')                           0                       0
# Mean                                       0.247241                0.124471
# Ratio_mean                                0.0446144               0.0224607
#
#                              Synset('discipline.n.02')  \
# Synset('information.n.05')                    0.622355
# Synset('understanding.n.01')                   3.08626
# Synset('trouble.n.01')                         3.08626
# Synset('software.n.01')                       0.622355
# Synset('discipline.n.02')                            0
# Synset('hardware.n.03')                              0
# Synset('computer.n.01')                              0
# Synset('summons.n.03')                               0
# Synset('particular.n.03')                            0
# Synset('science.n.01')                               0
# Synset('design.n.06')                                0
# Synset('sphere.n.01')                                0
# Synset('scientist.n.01')                             0
# Synset('engineering.n.03')                           0
# Synset('terminus.n.03')                              0
# Mean                                          0.494482
# Ratio_mean                                   0.0892289
#
#                              Synset('hardware.n.03') Synset('computer.n.01')  \
# Synset('information.n.05')                        -0                      -0
# Synset('understanding.n.01')                      -0                      -0
# Synset('trouble.n.01')                            -0                      -0
# Synset('software.n.01')                           -0                      -0
# Synset('discipline.n.02')                         -0                      -0
# Synset('hardware.n.03')                            0                 1.27313
# Synset('computer.n.01')                            0                       0
# Synset('summons.n.03')                             0                       0
# Synset('particular.n.03')                          0                       0
# Synset('science.n.01')                             0                       0
# Synset('design.n.06')                              0                       0
# Synset('sphere.n.01')                              0                       0
# Synset('scientist.n.01')                           0                       0
# Synset('engineering.n.03')                         0                       0
# Synset('terminus.n.03')                            0                       0
# Mean                                               0               0.0848755
# Ratio_mean                                         0               0.0153157
#
#                              Synset('summons.n.03') Synset('particular.n.03')  \
# Synset('information.n.05')                 0.622355                  0.622355
# Synset('understanding.n.01')               0.622355                  0.622355
# Synset('trouble.n.01')                     0.622355                  0.622355
# Synset('software.n.01')                     4.20093                   2.88435
# Synset('discipline.n.02')                  0.622355                  0.622355
# Synset('hardware.n.03')                          -0                        -0
# Synset('computer.n.01')                          -0                        -0
# Synset('summons.n.03')                            0                   2.88435
# Synset('particular.n.03')                         0                         0
# Synset('science.n.01')                            0                         0
# Synset('design.n.06')                             0                         0
# Synset('sphere.n.01')                             0                         0
# Synset('scientist.n.01')                          0                         0
# Synset('engineering.n.03')                        0                         0
# Synset('terminus.n.03')                           0                         0
# Mean                                       0.446023                  0.550542
# Ratio_mean                                0.0804845                 0.0993448
#
#                              Synset('science.n.01') Synset('design.n.06')  \
# Synset('information.n.05')                 0.622355                    -0
# Synset('understanding.n.01')                3.08626                    -0
# Synset('trouble.n.01')                      3.08626                    -0
# Synset('software.n.01')                    0.622355                    -0
# Synset('discipline.n.02')                   3.08626                    -0
# Synset('hardware.n.03')                          -0               1.27313
# Synset('computer.n.01')                          -0               2.56104
# Synset('summons.n.03')                     0.622355                    -0
# Synset('particular.n.03')                  0.622355                    -0
# Synset('science.n.01')                            0                    -0
# Synset('design.n.06')                             0                     0
# Synset('sphere.n.01')                             0                     0
# Synset('scientist.n.01')                          0                     0
# Synset('engineering.n.03')                        0                     0
# Synset('terminus.n.03')                           0                     0
# Mean                                       0.783213              0.255612
# Ratio_mean                                  0.14133             0.0461249
#
#                              Synset('sphere.n.01') Synset('scientist.n.01')  \
# Synset('information.n.05')                0.622355                       -0
# Synset('understanding.n.01')              0.622355                       -0
# Synset('trouble.n.01')                    0.622355                       -0
# Synset('software.n.01')                   0.622355                       -0
# Synset('discipline.n.02')                 0.622355                       -0
# Synset('hardware.n.03')                         -0                  1.27313
# Synset('computer.n.01')                         -0                  1.55201
# Synset('summons.n.03')                    0.622355                       -0
# Synset('particular.n.03')                 0.622355                       -0
# Synset('science.n.01')                    0.622355                       -0
# Synset('design.n.06')                           -0                  1.55201
# Synset('sphere.n.01')                            0                       -0
# Synset('scientist.n.01')                         0                        0
# Synset('engineering.n.03')                       0                        0
# Synset('terminus.n.03')                          0                        0
# Mean                                      0.331923                  0.29181
# Ratio_mean                               0.0598951                 0.052657
#
#                              Synset('engineering.n.03')  \
# Synset('information.n.05')                           -0
# Synset('understanding.n.01')                         -0
# Synset('trouble.n.01')                               -0
# Synset('software.n.01')                              -0
# Synset('discipline.n.02')                            -0
# Synset('hardware.n.03')                         1.27313
# Synset('computer.n.01')                         2.56104
# Synset('summons.n.03')                               -0
# Synset('particular.n.03')                            -0
# Synset('science.n.01')                               -0
# Synset('design.n.06')                           2.56104
# Synset('sphere.n.01')                                -0
# Synset('scientist.n.01')                        1.55201
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
# Mean                                           0.529816
# Ratio_mean                                    0.0956048
#
#                              Synset('terminus.n.03')
# Synset('information.n.05')                  0.622355
# Synset('understanding.n.01')                0.622355
# Synset('trouble.n.01')                      0.622355
# Synset('software.n.01')                     0.622355
# Synset('discipline.n.02')                   0.622355
# Synset('hardware.n.03')                      1.27313
# Synset('computer.n.01')                      2.56104
# Synset('summons.n.03')                      0.622355
# Synset('particular.n.03')                   0.622355
# Synset('science.n.01')                      0.622355
# Synset('design.n.06')                        4.91124
# Synset('sphere.n.01')                         2.5661
# Synset('scientist.n.01')                     1.55201
# Synset('engineering.n.03')                   2.56104
# Synset('terminus.n.03')                            0
# Mean                                         1.36023
# Ratio_mean                                  0.245452

# %%
'''
multible each pragraph element in ratio of frequancy
'''
def pragraph_ratio_mean(res_df,rmv_red_ratio):
    pragraph_ratio_values=res_df.values*rmv_red_ratio.T['Ratio'].T.values
    pragraph_ratio_df= pd.DataFrame(pragraph_ratio_values,index=res_df.index, columns=res_df.columns)
    pragraph_ratio_df_mean=add_mean_ratio(pragraph_ratio_df)
    return pragraph_ratio_df_mean

# %%
'''
multible each pragraph element in freq of frequancy
'''
def pragraph_freq_mean(res_df,rmv_red_ratio):
    pragraph_freq_values=res_df.values*rmv_red_ratio.T['Freq'].T.values
    pragraph_freq_df= pd.DataFrame(pragraph_freq_values,index=res_df.index, columns=res_df.columns)
    pragraph_freq_df_mean=add_mean_ratio(pragraph_freq_df)
    return pragraph_freq_df_mean

# %%
pragraph_ratio_mean_res=pragraph_ratio_mean(res_df,rmv_red_ratio)
pragraph_ratio_mean_res
# Out:
#                              Synset('information.n.05')  \
# Synset('information.n.05')                            0
# Synset('understanding.n.01')                          0
# Synset('trouble.n.01')                                0
# Synset('software.n.01')                               0
# Synset('discipline.n.02')                             0
# Synset('hardware.n.03')                               0
# Synset('computer.n.01')                               0
# Synset('summons.n.03')                                0
# Synset('particular.n.03')                             0
# Synset('science.n.01')                                0
# Synset('design.n.06')                                 0
# Synset('sphere.n.01')                                 0
# Synset('scientist.n.01')                              0
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
# Mean                                                  0
# Ratio_mean                                            0
#
#                              Synset('understanding.n.01')  \
# Synset('information.n.05')                      0.0248942
# Synset('understanding.n.01')                            0
# Synset('trouble.n.01')                                  0
# Synset('software.n.01')                                 0
# Synset('discipline.n.02')                               0
# Synset('hardware.n.03')                                 0
# Synset('computer.n.01')                                 0
# Synset('summons.n.03')                                  0
# Synset('particular.n.03')                               0
# Synset('science.n.01')                                  0
# Synset('design.n.06')                                   0
# Synset('sphere.n.01')                                   0
# Synset('scientist.n.01')                                0
# Synset('engineering.n.03')                              0
# Synset('terminus.n.03')                                 0
# Mean                                           0.00165961
# Ratio_mean                                      0.0044011
#
#                              Synset('trouble.n.01') Synset('software.n.01')  \
# Synset('information.n.05')                0.0311177               0.0311177
# Synset('understanding.n.01')               0.154313               0.0311177
# Synset('trouble.n.01')                            0               0.0311177
# Synset('software.n.01')                           0                       0
# Synset('discipline.n.02')                         0                       0
# Synset('hardware.n.03')                           0                       0
# Synset('computer.n.01')                           0                       0
# Synset('summons.n.03')                            0                       0
# Synset('particular.n.03')                         0                       0
# Synset('science.n.01')                            0                       0
# Synset('design.n.06')                             0                       0
# Synset('sphere.n.01')                             0                       0
# Synset('scientist.n.01')                          0                       0
# Synset('engineering.n.03')                        0                       0
# Synset('terminus.n.03')                           0                       0
# Mean                                      0.0123621              0.00622355
# Ratio_mean                                0.0327827               0.0165041
#
#                              Synset('discipline.n.02')  \
# Synset('information.n.05')                   0.0560119
# Synset('understanding.n.01')                  0.277763
# Synset('trouble.n.01')                        0.277763
# Synset('software.n.01')                      0.0560119
# Synset('discipline.n.02')                            0
# Synset('hardware.n.03')                              0
# Synset('computer.n.01')                              0
# Synset('summons.n.03')                               0
# Synset('particular.n.03')                            0
# Synset('science.n.01')                               0
# Synset('design.n.06')                                0
# Synset('sphere.n.01')                                0
# Synset('scientist.n.01')                             0
# Synset('engineering.n.03')                           0
# Synset('terminus.n.03')                              0
# Mean                                         0.0445034
# Ratio_mean                                    0.118018
#
#                              Synset('hardware.n.03') Synset('computer.n.01')  \
# Synset('information.n.05')                        -0                      -0
# Synset('understanding.n.01')                      -0                      -0
# Synset('trouble.n.01')                            -0                      -0
# Synset('software.n.01')                           -0                      -0
# Synset('discipline.n.02')                         -0                      -0
# Synset('hardware.n.03')                            0                0.280089
# Synset('computer.n.01')                            0                       0
# Synset('summons.n.03')                             0                       0
# Synset('particular.n.03')                          0                       0
# Synset('science.n.01')                             0                       0
# Synset('design.n.06')                              0                       0
# Synset('sphere.n.01')                              0                       0
# Synset('scientist.n.01')                           0                       0
# Synset('engineering.n.03')                         0                       0
# Synset('terminus.n.03')                            0                       0
# Mean                                               0               0.0186726
# Ratio_mean                                         0               0.0495176
#
#                              Synset('summons.n.03') Synset('particular.n.03')  \
# Synset('information.n.05')                0.0248942                 0.0186706
# Synset('understanding.n.01')              0.0248942                 0.0186706
# Synset('trouble.n.01')                    0.0248942                 0.0186706
# Synset('software.n.01')                    0.168037                 0.0865306
# Synset('discipline.n.02')                 0.0248942                 0.0186706
# Synset('hardware.n.03')                          -0                        -0
# Synset('computer.n.01')                          -0                        -0
# Synset('summons.n.03')                            0                 0.0865306
# Synset('particular.n.03')                         0                         0
# Synset('science.n.01')                            0                         0
# Synset('design.n.06')                             0                         0
# Synset('sphere.n.01')                             0                         0
# Synset('scientist.n.01')                          0                         0
# Synset('engineering.n.03')                        0                         0
# Synset('terminus.n.03')                           0                         0
# Mean                                      0.0178409                 0.0165163
# Ratio_mean                                 0.047312                 0.0437992
#
#                              Synset('science.n.01') Synset('design.n.06')  \
# Synset('information.n.05')                 0.118247                    -0
# Synset('understanding.n.01')                0.58639                    -0
# Synset('trouble.n.01')                      0.58639                    -0
# Synset('software.n.01')                    0.118247                    -0
# Synset('discipline.n.02')                   0.58639                    -0
# Synset('hardware.n.03')                          -0              0.076388
# Synset('computer.n.01')                          -0              0.153663
# Synset('summons.n.03')                     0.118247                    -0
# Synset('particular.n.03')                  0.118247                    -0
# Synset('science.n.01')                            0                    -0
# Synset('design.n.06')                             0                     0
# Synset('sphere.n.01')                             0                     0
# Synset('scientist.n.01')                          0                     0
# Synset('engineering.n.03')                        0                     0
# Synset('terminus.n.03')                           0                     0
# Mean                                       0.148811             0.0153367
# Ratio_mean                                 0.394628             0.0406711
#
#                              Synset('sphere.n.01') Synset('scientist.n.01')  \
# Synset('information.n.05')               0.0248942                       -0
# Synset('understanding.n.01')             0.0248942                       -0
# Synset('trouble.n.01')                   0.0248942                       -0
# Synset('software.n.01')                  0.0248942                       -0
# Synset('discipline.n.02')                0.0248942                       -0
# Synset('hardware.n.03')                         -0                0.0636566
# Synset('computer.n.01')                         -0                0.0776006
# Synset('summons.n.03')                   0.0248942                       -0
# Synset('particular.n.03')                0.0248942                       -0
# Synset('science.n.01')                   0.0248942                       -0
# Synset('design.n.06')                           -0                0.0776006
# Synset('sphere.n.01')                            0                       -0
# Synset('scientist.n.01')                         0                        0
# Synset('engineering.n.03')                       0                        0
# Synset('terminus.n.03')                          0                        0
# Mean                                     0.0132769                0.0145905
# Ratio_mean                               0.0352088                0.0386923
#
#                              Synset('engineering.n.03')  \
# Synset('information.n.05')                           -0
# Synset('understanding.n.01')                         -0
# Synset('trouble.n.01')                               -0
# Synset('software.n.01')                              -0
# Synset('discipline.n.02')                            -0
# Synset('hardware.n.03')                       0.0636566
# Synset('computer.n.01')                        0.128052
# Synset('summons.n.03')                               -0
# Synset('particular.n.03')                            -0
# Synset('science.n.01')                               -0
# Synset('design.n.06')                          0.128052
# Synset('sphere.n.01')                                -0
# Synset('scientist.n.01')                      0.0776006
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
# Mean                                          0.0264908
# Ratio_mean                                    0.0702504
#
#                              Synset('terminus.n.03')
# Synset('information.n.05')                 0.0186706
# Synset('understanding.n.01')               0.0186706
# Synset('trouble.n.01')                     0.0186706
# Synset('software.n.01')                    0.0186706
# Synset('discipline.n.02')                  0.0186706
# Synset('hardware.n.03')                     0.038194
# Synset('computer.n.01')                    0.0768313
# Synset('summons.n.03')                     0.0186706
# Synset('particular.n.03')                  0.0186706
# Synset('science.n.01')                     0.0186706
# Synset('design.n.06')                       0.147337
# Synset('sphere.n.01')                      0.0769829
# Synset('scientist.n.01')                   0.0465604
# Synset('engineering.n.03')                 0.0768313
# Synset('terminus.n.03')                            0
# Mean                                       0.0408068
# Ratio_mean                                  0.108215

# %%
pragraph_freq_mean_res=pragraph_freq_mean(res_df,rmv_red_ratio)
pragraph_freq_mean_res
# Out:
#                              Synset('information.n.05')  \
# Synset('information.n.05')                            0
# Synset('understanding.n.01')                          0
# Synset('trouble.n.01')                                0
# Synset('software.n.01')                               0
# Synset('discipline.n.02')                             0
# Synset('hardware.n.03')                               0
# Synset('computer.n.01')                               0
# Synset('summons.n.03')                                0
# Synset('particular.n.03')                             0
# Synset('science.n.01')                                0
# Synset('design.n.06')                                 0
# Synset('sphere.n.01')                                 0
# Synset('scientist.n.01')                              0
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
# Mean                                                  0
# Ratio_mean                                            0
#
#                              Synset('understanding.n.01')  \
# Synset('information.n.05')                        2.48942
# Synset('understanding.n.01')                            0
# Synset('trouble.n.01')                                  0
# Synset('software.n.01')                                 0
# Synset('discipline.n.02')                               0
# Synset('hardware.n.03')                                 0
# Synset('computer.n.01')                                 0
# Synset('summons.n.03')                                  0
# Synset('particular.n.03')                               0
# Synset('science.n.01')                                  0
# Synset('design.n.06')                                   0
# Synset('sphere.n.01')                                   0
# Synset('scientist.n.01')                                0
# Synset('engineering.n.03')                              0
# Synset('terminus.n.03')                                 0
# Mean                                             0.165961
# Ratio_mean                                      0.0044011
#
#                              Synset('trouble.n.01') Synset('software.n.01')  \
# Synset('information.n.05')                  3.11177                 3.11177
# Synset('understanding.n.01')                15.4313                 3.11177
# Synset('trouble.n.01')                            0                 3.11177
# Synset('software.n.01')                           0                       0
# Synset('discipline.n.02')                         0                       0
# Synset('hardware.n.03')                           0                       0
# Synset('computer.n.01')                           0                       0
# Synset('summons.n.03')                            0                       0
# Synset('particular.n.03')                         0                       0
# Synset('science.n.01')                            0                       0
# Synset('design.n.06')                             0                       0
# Synset('sphere.n.01')                             0                       0
# Synset('scientist.n.01')                          0                       0
# Synset('engineering.n.03')                        0                       0
# Synset('terminus.n.03')                           0                       0
# Mean                                        1.23621                0.622355
# Ratio_mean                                0.0327827               0.0165041
#
#                              Synset('discipline.n.02')  \
# Synset('information.n.05')                     5.60119
# Synset('understanding.n.01')                   27.7763
# Synset('trouble.n.01')                         27.7763
# Synset('software.n.01')                        5.60119
# Synset('discipline.n.02')                            0
# Synset('hardware.n.03')                              0
# Synset('computer.n.01')                              0
# Synset('summons.n.03')                               0
# Synset('particular.n.03')                            0
# Synset('science.n.01')                               0
# Synset('design.n.06')                                0
# Synset('sphere.n.01')                                0
# Synset('scientist.n.01')                             0
# Synset('engineering.n.03')                           0
# Synset('terminus.n.03')                              0
# Mean                                           4.45034
# Ratio_mean                                    0.118018
#
#                              Synset('hardware.n.03') Synset('computer.n.01')  \
# Synset('information.n.05')                        -0                      -0
# Synset('understanding.n.01')                      -0                      -0
# Synset('trouble.n.01')                            -0                      -0
# Synset('software.n.01')                           -0                      -0
# Synset('discipline.n.02')                         -0                      -0
# Synset('hardware.n.03')                            0                 28.0089
# Synset('computer.n.01')                            0                       0
# Synset('summons.n.03')                             0                       0
# Synset('particular.n.03')                          0                       0
# Synset('science.n.01')                             0                       0
# Synset('design.n.06')                              0                       0
# Synset('sphere.n.01')                              0                       0
# Synset('scientist.n.01')                           0                       0
# Synset('engineering.n.03')                         0                       0
# Synset('terminus.n.03')                            0                       0
# Mean                                               0                 1.86726
# Ratio_mean                                         0               0.0495176
#
#                              Synset('summons.n.03') Synset('particular.n.03')  \
# Synset('information.n.05')                  2.48942                   1.86706
# Synset('understanding.n.01')                2.48942                   1.86706
# Synset('trouble.n.01')                      2.48942                   1.86706
# Synset('software.n.01')                     16.8037                   8.65306
# Synset('discipline.n.02')                   2.48942                   1.86706
# Synset('hardware.n.03')                          -0                        -0
# Synset('computer.n.01')                          -0                        -0
# Synset('summons.n.03')                            0                   8.65306
# Synset('particular.n.03')                         0                         0
# Synset('science.n.01')                            0                         0
# Synset('design.n.06')                             0                         0
# Synset('sphere.n.01')                             0                         0
# Synset('scientist.n.01')                          0                         0
# Synset('engineering.n.03')                        0                         0
# Synset('terminus.n.03')                           0                         0
# Mean                                        1.78409                   1.65163
# Ratio_mean                                 0.047312                 0.0437992
#
#                              Synset('science.n.01') Synset('design.n.06')  \
# Synset('information.n.05')                  11.8247                    -0
# Synset('understanding.n.01')                 58.639                    -0
# Synset('trouble.n.01')                       58.639                    -0
# Synset('software.n.01')                     11.8247                    -0
# Synset('discipline.n.02')                    58.639                    -0
# Synset('hardware.n.03')                          -0                7.6388
# Synset('computer.n.01')                          -0               15.3663
# Synset('summons.n.03')                      11.8247                    -0
# Synset('particular.n.03')                   11.8247                    -0
# Synset('science.n.01')                            0                    -0
# Synset('design.n.06')                             0                     0
# Synset('sphere.n.01')                             0                     0
# Synset('scientist.n.01')                          0                     0
# Synset('engineering.n.03')                        0                     0
# Synset('terminus.n.03')                           0                     0
# Mean                                        14.8811               1.53367
# Ratio_mean                                 0.394628             0.0406711
#
#                              Synset('sphere.n.01') Synset('scientist.n.01')  \
# Synset('information.n.05')                 2.48942                       -0
# Synset('understanding.n.01')               2.48942                       -0
# Synset('trouble.n.01')                     2.48942                       -0
# Synset('software.n.01')                    2.48942                       -0
# Synset('discipline.n.02')                  2.48942                       -0
# Synset('hardware.n.03')                         -0                  6.36566
# Synset('computer.n.01')                         -0                  7.76006
# Synset('summons.n.03')                     2.48942                       -0
# Synset('particular.n.03')                  2.48942                       -0
# Synset('science.n.01')                     2.48942                       -0
# Synset('design.n.06')                           -0                  7.76006
# Synset('sphere.n.01')                            0                       -0
# Synset('scientist.n.01')                         0                        0
# Synset('engineering.n.03')                       0                        0
# Synset('terminus.n.03')                          0                        0
# Mean                                       1.32769                  1.45905
# Ratio_mean                               0.0352088                0.0386923
#
#                              Synset('engineering.n.03')  \
# Synset('information.n.05')                           -0
# Synset('understanding.n.01')                         -0
# Synset('trouble.n.01')                               -0
# Synset('software.n.01')                              -0
# Synset('discipline.n.02')                            -0
# Synset('hardware.n.03')                         6.36566
# Synset('computer.n.01')                         12.8052
# Synset('summons.n.03')                               -0
# Synset('particular.n.03')                            -0
# Synset('science.n.01')                               -0
# Synset('design.n.06')                           12.8052
# Synset('sphere.n.01')                                -0
# Synset('scientist.n.01')                        7.76006
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
# Mean                                            2.64908
# Ratio_mean                                    0.0702504
#
#                              Synset('terminus.n.03')
# Synset('information.n.05')                   1.86706
# Synset('understanding.n.01')                 1.86706
# Synset('trouble.n.01')                       1.86706
# Synset('software.n.01')                      1.86706
# Synset('discipline.n.02')                    1.86706
# Synset('hardware.n.03')                       3.8194
# Synset('computer.n.01')                      7.68313
# Synset('summons.n.03')                       1.86706
# Synset('particular.n.03')                    1.86706
# Synset('science.n.01')                       1.86706
# Synset('design.n.06')                        14.7337
# Synset('sphere.n.01')                        7.69829
# Synset('scientist.n.01')                     4.65604
# Synset('engineering.n.03')                   7.68313
# Synset('terminus.n.03')                            0
# Mean                                         4.08068
# Ratio_mean                                  0.108215

# %%
pragraph_ratio_mean_jcn=pragraph_ratio_mean(jcn_df,rmv_red_ratio)
pragraph_ratio_mean_jcn
# Out:
#                              Synset('information.n.05')  \
# Synset('information.n.05')                            0
# Synset('understanding.n.01')                          0
# Synset('trouble.n.01')                                0
# Synset('software.n.01')                               0
# Synset('discipline.n.02')                             0
# Synset('hardware.n.03')                               0
# Synset('computer.n.01')                               0
# Synset('summons.n.03')                                0
# Synset('particular.n.03')                             0
# Synset('science.n.01')                                0
# Synset('design.n.06')                                 0
# Synset('sphere.n.01')                                 0
# Synset('scientist.n.01')                              0
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
# Mean                                                  0
# Ratio_mean                                            0
#
#                              Synset('understanding.n.01')  \
# Synset('information.n.05')                     0.00249427
# Synset('understanding.n.01')                            0
# Synset('trouble.n.01')                                  0
# Synset('software.n.01')                                 0
# Synset('discipline.n.02')                               0
# Synset('hardware.n.03')                                 0
# Synset('computer.n.01')                                 0
# Synset('summons.n.03')                                  0
# Synset('particular.n.03')                               0
# Synset('science.n.01')                                  0
# Synset('design.n.06')                                   0
# Synset('sphere.n.01')                                   0
# Synset('scientist.n.01')                                0
# Synset('engineering.n.03')                              0
# Synset('terminus.n.03')                                 0
# Mean                                          0.000166285
# Ratio_mean                                     0.00517119
#
#                              Synset('trouble.n.01') Synset('software.n.01')  \
# Synset('information.n.05')               0.00315253              0.00328754
# Synset('understanding.n.01')             0.00506332               0.0035628
# Synset('trouble.n.01')                            0              0.00360818
# Synset('software.n.01')                           0                       0
# Synset('discipline.n.02')                         0                       0
# Synset('hardware.n.03')                           0                       0
# Synset('computer.n.01')                           0                       0
# Synset('summons.n.03')                            0                       0
# Synset('particular.n.03')                         0                       0
# Synset('science.n.01')                            0                       0
# Synset('design.n.06')                             0                       0
# Synset('sphere.n.01')                             0                       0
# Synset('scientist.n.01')                          0                       0
# Synset('engineering.n.03')                        0                       0
# Synset('terminus.n.03')                           0                       0
# Mean                                    0.000547724             0.000697235
# Ratio_mean                                0.0170333               0.0216829
#
#                              Synset('discipline.n.02')  \
# Synset('information.n.05')                  0.00464978
# Synset('understanding.n.01')                0.00673127
# Synset('trouble.n.01')                       0.0068213
# Synset('software.n.01')                     0.00518645
# Synset('discipline.n.02')                            0
# Synset('hardware.n.03')                              0
# Synset('computer.n.01')                              0
# Synset('summons.n.03')                               0
# Synset('particular.n.03')                            0
# Synset('science.n.01')                               0
# Synset('design.n.06')                                0
# Synset('sphere.n.01')                                0
# Synset('scientist.n.01')                             0
# Synset('engineering.n.03')                           0
# Synset('terminus.n.03')                              0
# Mean                                        0.00155925
# Ratio_mean                                   0.0484902
#
#                              Synset('hardware.n.03') Synset('computer.n.01')  \
# Synset('information.n.05')                0.00171819               0.0133594
# Synset('understanding.n.01')              0.00184217               0.0143859
# Synset('trouble.n.01')                    0.00186235               0.0145539
# Synset('software.n.01')                   0.00194082               0.0152092
# Synset('discipline.n.02')                 0.00153029               0.0118205
# Synset('hardware.n.03')                            0               0.0170321
# Synset('computer.n.01')                            0                       0
# Synset('summons.n.03')                             0                       0
# Synset('particular.n.03')                          0                       0
# Synset('science.n.01')                             0                       0
# Synset('design.n.06')                              0                       0
# Synset('sphere.n.01')                              0                       0
# Synset('scientist.n.01')                           0                       0
# Synset('engineering.n.03')                         0                       0
# Synset('terminus.n.03')                            0                       0
# Mean                                     0.000592921              0.00575741
# Ratio_mean                                 0.0184389                0.179046
#
#                              Synset('summons.n.03') Synset('particular.n.03')  \
# Synset('information.n.05')               0.00231917                0.00160003
# Synset('understanding.n.01')             0.00248872                0.00170701
# Synset('trouble.n.01')                   0.00251635                0.00172433
# Synset('software.n.01')                  0.00465502                0.00238669
# Synset('discipline.n.02')                0.00206275                0.00143585
# Synset('hardware.n.03')                  0.00228624                0.00157911
# Synset('computer.n.01')                  0.00242372                0.00166615
# Synset('summons.n.03')                            0                0.00205362
# Synset('particular.n.03')                         0                         0
# Synset('science.n.01')                            0                         0
# Synset('design.n.06')                             0                         0
# Synset('sphere.n.01')                             0                         0
# Synset('scientist.n.01')                          0                         0
# Synset('engineering.n.03')                        0                         0
# Synset('terminus.n.03')                           0                         0
# Mean                                     0.00125013               0.000943519
# Ratio_mean                                 0.038877                 0.0293419
#
#                              Synset('science.n.01') Synset('design.n.06')  \
# Synset('information.n.05')                0.0125539            0.00313191
# Synset('understanding.n.01')              0.0207663            0.00333656
# Synset('trouble.n.01')                    0.0211747            0.00336963
# Synset('software.n.01')                   0.0144685            0.00349756
# Synset('discipline.n.02')                 0.0152384            0.00281669
# Synset('hardware.n.03')                   0.0123511            0.00384451
# Synset('computer.n.01')                   0.0132029            0.00473511
# Synset('summons.n.03')                    0.0125242            0.00312607
# Synset('particular.n.03')                 0.0113959            0.00289918
# Synset('science.n.01')                            0            0.00351275
# Synset('design.n.06')                             0                     0
# Synset('sphere.n.01')                             0                     0
# Synset('scientist.n.01')                          0                     0
# Synset('engineering.n.03')                        0                     0
# Synset('terminus.n.03')                           0                     0
# Mean                                     0.00891173            0.00228466
# Ratio_mean                                  0.27714             0.0710493
#
#                              Synset('sphere.n.01') Synset('scientist.n.01')  \
# Synset('information.n.05')              0.00251347               0.00330271
# Synset('understanding.n.01')            0.00271384               0.00358062
# Synset('trouble.n.01')                  0.00274673               0.00362645
# Synset('software.n.01')                 0.00287533               0.00380626
# Synset('discipline.n.02')               0.00221505                 0.002893
# Synset('hardware.n.03')                 0.00247484               0.00431477
# Synset('computer.n.01')                 0.00263674               0.00495177
# Synset('summons.n.03')                  0.00250783               0.00329492
# Synset('particular.n.03')               0.00229198               0.00299815
# Synset('science.n.01')                  0.00289074               0.00382787
# Synset('design.n.06')                   0.00223962               0.00391013
# Synset('sphere.n.01')                            0                0.0036123
# Synset('scientist.n.01')                         0                        0
# Synset('engineering.n.03')                       0                        0
# Synset('terminus.n.03')                          0                        0
# Mean                                    0.00187375               0.00294126
# Ratio_mean                               0.0582704                0.0914685
#
#                              Synset('engineering.n.03')  \
# Synset('information.n.05')                   0.00257306
# Synset('understanding.n.01')                 0.00273867
# Synset('trouble.n.01')                        0.0027654
# Synset('software.n.01')                      0.00286874
# Synset('discipline.n.02')                    0.00231738
# Synset('hardware.n.03')                       0.0031484
# Synset('computer.n.01')                      0.00386227
# Synset('summons.n.03')                       0.00256833
# Synset('particular.n.03')                    0.00238437
# Synset('science.n.01')                         0.002881
# Synset('design.n.06')                        0.00319782
# Synset('sphere.n.01')                        0.00275716
# Synset('scientist.n.01')                     0.00382798
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
# Mean                                         0.00252604
# Ratio_mean                                    0.0785557
#
#                              Synset('terminus.n.03')
# Synset('information.n.05')                0.00186213
# Synset('understanding.n.01')              0.00200863
# Synset('trouble.n.01')                    0.00203265
# Synset('software.n.01')                    0.0021265
# Synset('discipline.n.02')                 0.00164343
# Synset('hardware.n.03')                    0.0022115
# Synset('computer.n.01')                   0.00282218
# Synset('summons.n.03')                      0.001858
# Synset('particular.n.03')                 0.00169987
# Synset('science.n.01')                    0.00213773
# Synset('design.n.06')                     0.00343113
# Synset('sphere.n.01')                     0.00272937
# Synset('scientist.n.01')                  0.00279172
# Synset('engineering.n.03')                0.00220679
# Synset('terminus.n.03')                            0
# Mean                                      0.00210411
# Ratio_mean                                 0.0654343

# %%
pragraph_freq_mean_jcn=pragraph_freq_mean(jcn_df,rmv_red_ratio)
pragraph_freq_mean_jcn
# Out:
#                              Synset('information.n.05')  \
# Synset('information.n.05')                            0
# Synset('understanding.n.01')                          0
# Synset('trouble.n.01')                                0
# Synset('software.n.01')                               0
# Synset('discipline.n.02')                             0
# Synset('hardware.n.03')                               0
# Synset('computer.n.01')                               0
# Synset('summons.n.03')                                0
# Synset('particular.n.03')                             0
# Synset('science.n.01')                                0
# Synset('design.n.06')                                 0
# Synset('sphere.n.01')                                 0
# Synset('scientist.n.01')                              0
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
# Mean                                                  0
# Ratio_mean                                            0
#
#                              Synset('understanding.n.01')  \
# Synset('information.n.05')                       0.249427
# Synset('understanding.n.01')                            0
# Synset('trouble.n.01')                                  0
# Synset('software.n.01')                                 0
# Synset('discipline.n.02')                               0
# Synset('hardware.n.03')                                 0
# Synset('computer.n.01')                                 0
# Synset('summons.n.03')                                  0
# Synset('particular.n.03')                               0
# Synset('science.n.01')                                  0
# Synset('design.n.06')                                   0
# Synset('sphere.n.01')                                   0
# Synset('scientist.n.01')                                0
# Synset('engineering.n.03')                              0
# Synset('terminus.n.03')                                 0
# Mean                                            0.0166285
# Ratio_mean                                     0.00517119
#
#                              Synset('trouble.n.01') Synset('software.n.01')  \
# Synset('information.n.05')                 0.315253                0.328754
# Synset('understanding.n.01')               0.506332                 0.35628
# Synset('trouble.n.01')                            0                0.360818
# Synset('software.n.01')                           0                       0
# Synset('discipline.n.02')                         0                       0
# Synset('hardware.n.03')                           0                       0
# Synset('computer.n.01')                           0                       0
# Synset('summons.n.03')                            0                       0
# Synset('particular.n.03')                         0                       0
# Synset('science.n.01')                            0                       0
# Synset('design.n.06')                             0                       0
# Synset('sphere.n.01')                             0                       0
# Synset('scientist.n.01')                          0                       0
# Synset('engineering.n.03')                        0                       0
# Synset('terminus.n.03')                           0                       0
# Mean                                      0.0547724               0.0697235
# Ratio_mean                                0.0170333               0.0216829
#
#                              Synset('discipline.n.02')  \
# Synset('information.n.05')                    0.464978
# Synset('understanding.n.01')                  0.673127
# Synset('trouble.n.01')                         0.68213
# Synset('software.n.01')                       0.518645
# Synset('discipline.n.02')                            0
# Synset('hardware.n.03')                              0
# Synset('computer.n.01')                              0
# Synset('summons.n.03')                               0
# Synset('particular.n.03')                            0
# Synset('science.n.01')                               0
# Synset('design.n.06')                                0
# Synset('sphere.n.01')                                0
# Synset('scientist.n.01')                             0
# Synset('engineering.n.03')                           0
# Synset('terminus.n.03')                              0
# Mean                                          0.155925
# Ratio_mean                                   0.0484902
#
#                              Synset('hardware.n.03') Synset('computer.n.01')  \
# Synset('information.n.05')                  0.171819                 1.33594
# Synset('understanding.n.01')                0.184217                 1.43859
# Synset('trouble.n.01')                      0.186235                 1.45539
# Synset('software.n.01')                     0.194082                 1.52092
# Synset('discipline.n.02')                   0.153029                 1.18205
# Synset('hardware.n.03')                            0                 1.70321
# Synset('computer.n.01')                            0                       0
# Synset('summons.n.03')                             0                       0
# Synset('particular.n.03')                          0                       0
# Synset('science.n.01')                             0                       0
# Synset('design.n.06')                              0                       0
# Synset('sphere.n.01')                              0                       0
# Synset('scientist.n.01')                           0                       0
# Synset('engineering.n.03')                         0                       0
# Synset('terminus.n.03')                            0                       0
# Mean                                       0.0592921                0.575741
# Ratio_mean                                 0.0184389                0.179046
#
#                              Synset('summons.n.03') Synset('particular.n.03')  \
# Synset('information.n.05')                 0.231917                  0.160003
# Synset('understanding.n.01')               0.248872                  0.170701
# Synset('trouble.n.01')                     0.251635                  0.172433
# Synset('software.n.01')                    0.465502                  0.238669
# Synset('discipline.n.02')                  0.206275                  0.143585
# Synset('hardware.n.03')                    0.228624                  0.157911
# Synset('computer.n.01')                    0.242372                  0.166615
# Synset('summons.n.03')                            0                  0.205362
# Synset('particular.n.03')                         0                         0
# Synset('science.n.01')                            0                         0
# Synset('design.n.06')                             0                         0
# Synset('sphere.n.01')                             0                         0
# Synset('scientist.n.01')                          0                         0
# Synset('engineering.n.03')                        0                         0
# Synset('terminus.n.03')                           0                         0
# Mean                                       0.125013                 0.0943519
# Ratio_mean                                 0.038877                 0.0293419
#
#                              Synset('science.n.01') Synset('design.n.06')  \
# Synset('information.n.05')                  1.25539              0.313191
# Synset('understanding.n.01')                2.07663              0.333656
# Synset('trouble.n.01')                      2.11747              0.336963
# Synset('software.n.01')                     1.44685              0.349756
# Synset('discipline.n.02')                   1.52384              0.281669
# Synset('hardware.n.03')                     1.23511              0.384451
# Synset('computer.n.01')                     1.32029              0.473511
# Synset('summons.n.03')                      1.25242              0.312607
# Synset('particular.n.03')                   1.13959              0.289918
# Synset('science.n.01')                            0              0.351275
# Synset('design.n.06')                             0                     0
# Synset('sphere.n.01')                             0                     0
# Synset('scientist.n.01')                          0                     0
# Synset('engineering.n.03')                        0                     0
# Synset('terminus.n.03')                           0                     0
# Mean                                       0.891173              0.228466
# Ratio_mean                                  0.27714             0.0710493
#
#                              Synset('sphere.n.01') Synset('scientist.n.01')  \
# Synset('information.n.05')                0.251347                 0.330271
# Synset('understanding.n.01')              0.271384                 0.358062
# Synset('trouble.n.01')                    0.274673                 0.362645
# Synset('software.n.01')                   0.287533                 0.380626
# Synset('discipline.n.02')                 0.221505                   0.2893
# Synset('hardware.n.03')                   0.247484                 0.431477
# Synset('computer.n.01')                   0.263674                 0.495177
# Synset('summons.n.03')                    0.250783                 0.329492
# Synset('particular.n.03')                 0.229198                 0.299815
# Synset('science.n.01')                    0.289074                 0.382787
# Synset('design.n.06')                     0.223962                 0.391013
# Synset('sphere.n.01')                            0                  0.36123
# Synset('scientist.n.01')                         0                        0
# Synset('engineering.n.03')                       0                        0
# Synset('terminus.n.03')                          0                        0
# Mean                                      0.187375                 0.294126
# Ratio_mean                               0.0582704                0.0914685
#
#                              Synset('engineering.n.03')  \
# Synset('information.n.05')                     0.257306
# Synset('understanding.n.01')                   0.273867
# Synset('trouble.n.01')                          0.27654
# Synset('software.n.01')                        0.286874
# Synset('discipline.n.02')                      0.231738
# Synset('hardware.n.03')                         0.31484
# Synset('computer.n.01')                        0.386227
# Synset('summons.n.03')                         0.256833
# Synset('particular.n.03')                      0.238437
# Synset('science.n.01')                           0.2881
# Synset('design.n.06')                          0.319782
# Synset('sphere.n.01')                          0.275716
# Synset('scientist.n.01')                       0.382798
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
# Mean                                           0.252604
# Ratio_mean                                    0.0785557
#
#                              Synset('terminus.n.03')
# Synset('information.n.05')                  0.186213
# Synset('understanding.n.01')                0.200863
# Synset('trouble.n.01')                      0.203265
# Synset('software.n.01')                      0.21265
# Synset('discipline.n.02')                   0.164343
# Synset('hardware.n.03')                      0.22115
# Synset('computer.n.01')                     0.282218
# Synset('summons.n.03')                        0.1858
# Synset('particular.n.03')                   0.169987
# Synset('science.n.01')                      0.213773
# Synset('design.n.06')                       0.343113
# Synset('sphere.n.01')                       0.272937
# Synset('scientist.n.01')                    0.279172
# Synset('engineering.n.03')                  0.220679
# Synset('terminus.n.03')                            0
# Mean                                        0.210411
# Ratio_mean                                 0.0654343

# %%
'''
to calculate (IC(c1) + IC(c2 )) by res and jcn
'''

def p_IC_C(res_df,jcn_df):
    ic=2*(res_df.values)
    pic= pd.DataFrame(jcn_df.values+ic,index=res_df.index, columns=res_df.columns)
    
    return pic

# %%
p_IC_C_df=p_IC_C(res_df,jcn_df)
p_IC_C_df
# Out:
#                              Synset('information.n.05')  \
# Synset('information.n.05')                            0
# Synset('understanding.n.01')                          0
# Synset('trouble.n.01')                                0
# Synset('software.n.01')                               0
# Synset('discipline.n.02')                             0
# Synset('hardware.n.03')                               0
# Synset('computer.n.01')                               0
# Synset('summons.n.03')                                0
# Synset('particular.n.03')                             0
# Synset('science.n.01')                                0
# Synset('design.n.06')                                 0
# Synset('sphere.n.01')                                 0
# Synset('scientist.n.01')                              0
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
#
#                              Synset('understanding.n.01')  \
# Synset('information.n.05')                        1.30707
# Synset('understanding.n.01')                            0
# Synset('trouble.n.01')                                  0
# Synset('software.n.01')                                 0
# Synset('discipline.n.02')                               0
# Synset('hardware.n.03')                                 0
# Synset('computer.n.01')                                 0
# Synset('summons.n.03')                                  0
# Synset('particular.n.03')                               0
# Synset('science.n.01')                                  0
# Synset('design.n.06')                                   0
# Synset('sphere.n.01')                                   0
# Synset('scientist.n.01')                                0
# Synset('engineering.n.03')                              0
# Synset('terminus.n.03')                                 0
#
#                              Synset('trouble.n.01') Synset('software.n.01')  \
# Synset('information.n.05')                  1.30776                 1.31046
# Synset('understanding.n.01')                6.27379                 1.31597
# Synset('trouble.n.01')                            0                 1.31687
# Synset('software.n.01')                           0                       0
# Synset('discipline.n.02')                         0                       0
# Synset('hardware.n.03')                           0                       0
# Synset('computer.n.01')                           0                       0
# Synset('summons.n.03')                            0                       0
# Synset('particular.n.03')                         0                       0
# Synset('science.n.01')                            0                       0
# Synset('design.n.06')                             0                       0
# Synset('sphere.n.01')                             0                       0
# Synset('scientist.n.01')                          0                       0
# Synset('engineering.n.03')                        0                       0
# Synset('terminus.n.03')                           0                       0
#
#                              Synset('discipline.n.02')  \
# Synset('information.n.05')                     1.29637
# Synset('understanding.n.01')                   6.24731
# Synset('trouble.n.01')                         6.24831
# Synset('software.n.01')                        1.30234
# Synset('discipline.n.02')                            0
# Synset('hardware.n.03')                              0
# Synset('computer.n.01')                              0
# Synset('summons.n.03')                               0
# Synset('particular.n.03')                            0
# Synset('science.n.01')                               0
# Synset('design.n.06')                                0
# Synset('sphere.n.01')                                0
# Synset('scientist.n.01')                             0
# Synset('engineering.n.03')                           0
# Synset('terminus.n.03')                              0
#
#                              Synset('hardware.n.03') Synset('computer.n.01')  \
# Synset('information.n.05')                 0.0572731               0.0607247
# Synset('understanding.n.01')               0.0614056               0.0653906
# Synset('trouble.n.01')                     0.0620783                0.066154
# Synset('software.n.01')                    0.0646942               0.0691328
# Synset('discipline.n.02')                  0.0510095               0.0537295
# Synset('hardware.n.03')                            0                 2.62368
# Synset('computer.n.01')                            0                       0
# Synset('summons.n.03')                             0                       0
# Synset('particular.n.03')                          0                       0
# Synset('science.n.01')                             0                       0
# Synset('design.n.06')                              0                       0
# Synset('sphere.n.01')                              0                       0
# Synset('scientist.n.01')                           0                       0
# Synset('engineering.n.03')                         0                       0
# Synset('terminus.n.03')                            0                       0
#
#                              Synset('summons.n.03') Synset('particular.n.03')  \
# Synset('information.n.05')                  1.30269                   1.29804
# Synset('understanding.n.01')                1.30693                   1.30161
# Synset('trouble.n.01')                      1.30762                   1.30219
# Synset('software.n.01')                     8.51823                   5.84827
# Synset('discipline.n.02')                   1.29628                   1.29257
# Synset('hardware.n.03')                    0.057156                  0.052637
# Synset('computer.n.01')                    0.060593                 0.0555383
# Synset('summons.n.03')                            0                   5.83716
# Synset('particular.n.03')                         0                         0
# Synset('science.n.01')                            0                         0
# Synset('design.n.06')                             0                         0
# Synset('sphere.n.01')                             0                         0
# Synset('scientist.n.01')                          0                         0
# Synset('engineering.n.03')                        0                         0
# Synset('terminus.n.03')                           0                         0
#
#                              Synset('science.n.01') Synset('design.n.06')  \
# Synset('information.n.05')                  1.31078             0.0521985
# Synset('understanding.n.01')                6.28182             0.0556093
# Synset('trouble.n.01')                      6.28397             0.0561604
# Synset('software.n.01')                     1.32086             0.0582927
# Synset('discipline.n.02')                   6.25272             0.0469448
# Synset('hardware.n.03')                    0.065006               2.61034
# Synset('computer.n.01')                    0.069489               5.20101
# Synset('summons.n.03')                      1.31063             0.0521011
# Synset('particular.n.03')                   1.30469             0.0483197
# Synset('science.n.01')                            0             0.0585458
# Synset('design.n.06')                             0                     0
# Synset('sphere.n.01')                             0                     0
# Synset('scientist.n.01')                          0                     0
# Synset('engineering.n.03')                        0                     0
# Synset('terminus.n.03')                           0                     0
#
#                              Synset('sphere.n.01') Synset('scientist.n.01')  \
# Synset('information.n.05')                 1.30755                0.0660541
# Synset('understanding.n.01')               1.31256                0.0716124
# Synset('trouble.n.01')                     1.31338                 0.072529
# Synset('software.n.01')                    1.31659                0.0761252
# Synset('discipline.n.02')                  1.30009                  0.05786
# Synset('hardware.n.03')                  0.0618709                  2.63256
# Synset('computer.n.01')                  0.0659185                  3.20306
# Synset('summons.n.03')                     1.30741                0.0658983
# Synset('particular.n.03')                  1.30201                 0.059963
# Synset('science.n.01')                     1.31698                0.0765573
# Synset('design.n.06')                    0.0559906                  3.18223
# Synset('sphere.n.01')                            0                 0.072246
# Synset('scientist.n.01')                         0                        0
# Synset('engineering.n.03')                       0                        0
# Synset('terminus.n.03')                          0                        0
#
#                              Synset('engineering.n.03')  \
# Synset('information.n.05')                    0.0514613
# Synset('understanding.n.01')                  0.0547734
# Synset('trouble.n.01')                         0.055308
# Synset('software.n.01')                       0.0573749
# Synset('discipline.n.02')                     0.0463477
# Synset('hardware.n.03')                         2.60923
# Synset('computer.n.01')                         5.19934
# Synset('summons.n.03')                        0.0513667
# Synset('particular.n.03')                     0.0476873
# Synset('science.n.01')                          0.05762
# Synset('design.n.06')                           5.18605
# Synset('sphere.n.01')                         0.0551433
# Synset('scientist.n.01')                        3.18058
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
#
#                              Synset('terminus.n.03')
# Synset('information.n.05')                   1.30678
# Synset('understanding.n.01')                 1.31166
# Synset('trouble.n.01')                       1.31246
# Synset('software.n.01')                      1.31559
# Synset('discipline.n.02')                    1.29949
# Synset('hardware.n.03')                      2.61998
# Synset('computer.n.01')                      5.21616
# Synset('summons.n.03')                       1.30664
# Synset('particular.n.03')                    1.30137
# Synset('science.n.01')                       1.31597
# Synset('design.n.06')                        9.93686
# Synset('sphere.n.01')                        5.22317
# Synset('scientist.n.01')                     3.19708
# Synset('engineering.n.03')                   5.19565
# Synset('terminus.n.03')                            0

# %%
pragraph_ratio_mean_pic=pragraph_ratio_mean(p_IC_C_df,rmv_red_ratio)
pragraph_ratio_mean_pic
# Out:
#                              Synset('information.n.05')  \
# Synset('information.n.05')                            0
# Synset('understanding.n.01')                          0
# Synset('trouble.n.01')                                0
# Synset('software.n.01')                               0
# Synset('discipline.n.02')                             0
# Synset('hardware.n.03')                               0
# Synset('computer.n.01')                               0
# Synset('summons.n.03')                                0
# Synset('particular.n.03')                             0
# Synset('science.n.01')                                0
# Synset('design.n.06')                                 0
# Synset('sphere.n.01')                                 0
# Synset('scientist.n.01')                              0
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
# Mean                                                  0
# Ratio_mean                                            0
#
#                              Synset('understanding.n.01')  \
# Synset('information.n.05')                      0.0522827
# Synset('understanding.n.01')                            0
# Synset('trouble.n.01')                                  0
# Synset('software.n.01')                                 0
# Synset('discipline.n.02')                               0
# Synset('hardware.n.03')                                 0
# Synset('computer.n.01')                                 0
# Synset('summons.n.03')                                  0
# Synset('particular.n.03')                               0
# Synset('science.n.01')                                  0
# Synset('design.n.06')                                   0
# Synset('sphere.n.01')                                   0
# Synset('scientist.n.01')                                0
# Synset('engineering.n.03')                              0
# Synset('terminus.n.03')                                 0
# Mean                                           0.00348551
# Ratio_mean                                     0.00443259
#
#                              Synset('trouble.n.01') Synset('software.n.01')  \
# Synset('information.n.05')                 0.065388                0.065523
# Synset('understanding.n.01')               0.313689               0.0657983
# Synset('trouble.n.01')                            0               0.0658436
# Synset('software.n.01')                           0                       0
# Synset('discipline.n.02')                         0                       0
# Synset('hardware.n.03')                           0                       0
# Synset('computer.n.01')                           0                       0
# Synset('summons.n.03')                            0                       0
# Synset('particular.n.03')                         0                       0
# Synset('science.n.01')                            0                       0
# Synset('design.n.06')                             0                       0
# Synset('sphere.n.01')                             0                       0
# Synset('scientist.n.01')                          0                       0
# Synset('engineering.n.03')                        0                       0
# Synset('terminus.n.03')                           0                       0
# Mean                                      0.0252718               0.0131443
# Ratio_mean                                0.0321387               0.0167159
#
#                              Synset('discipline.n.02')  \
# Synset('information.n.05')                    0.116674
# Synset('understanding.n.01')                  0.562258
# Synset('trouble.n.01')                        0.562348
# Synset('software.n.01')                        0.11721
# Synset('discipline.n.02')                            0
# Synset('hardware.n.03')                              0
# Synset('computer.n.01')                              0
# Synset('summons.n.03')                               0
# Synset('particular.n.03')                            0
# Synset('science.n.01')                               0
# Synset('design.n.06')                                0
# Synset('sphere.n.01')                                0
# Synset('scientist.n.01')                             0
# Synset('engineering.n.03')                           0
# Synset('terminus.n.03')                              0
# Mean                                          0.090566
# Ratio_mean                                    0.115175
#
#                              Synset('hardware.n.03') Synset('computer.n.01')  \
# Synset('information.n.05')                0.00171819               0.0133594
# Synset('understanding.n.01')              0.00184217               0.0143859
# Synset('trouble.n.01')                    0.00186235               0.0145539
# Synset('software.n.01')                   0.00194082               0.0152092
# Synset('discipline.n.02')                 0.00153029               0.0118205
# Synset('hardware.n.03')                            0                0.577211
# Synset('computer.n.01')                            0                       0
# Synset('summons.n.03')                             0                       0
# Synset('particular.n.03')                          0                       0
# Synset('science.n.01')                             0                       0
# Synset('design.n.06')                              0                       0
# Synset('sphere.n.01')                              0                       0
# Synset('scientist.n.01')                           0                       0
# Synset('engineering.n.03')                         0                       0
# Synset('terminus.n.03')                            0                       0
# Mean                                     0.000592921               0.0431026
# Ratio_mean                               0.000754029               0.0548144
#
#                              Synset('summons.n.03') Synset('particular.n.03')  \
# Synset('information.n.05')                0.0521075                 0.0389413
# Synset('understanding.n.01')              0.0522771                 0.0390483
# Synset('trouble.n.01')                    0.0523047                 0.0390656
# Synset('software.n.01')                    0.340729                  0.175448
# Synset('discipline.n.02')                 0.0518511                 0.0387771
# Synset('hardware.n.03')                  0.00228624                0.00157911
# Synset('computer.n.01')                  0.00242372                0.00166615
# Synset('summons.n.03')                            0                  0.175115
# Synset('particular.n.03')                         0                         0
# Synset('science.n.01')                            0                         0
# Synset('design.n.06')                             0                         0
# Synset('sphere.n.01')                             0                         0
# Synset('scientist.n.01')                          0                         0
# Synset('engineering.n.03')                        0                         0
# Synset('terminus.n.03')                           0                         0
# Mean                                       0.036932                  0.033976
# Ratio_mean                                0.0469671                  0.043208
#
#                              Synset('science.n.01') Synset('design.n.06')  \
# Synset('information.n.05')                 0.249049            0.00313191
# Synset('understanding.n.01')                1.19355            0.00333656
# Synset('trouble.n.01')                      1.19395            0.00336963
# Synset('software.n.01')                    0.250963            0.00349756
# Synset('discipline.n.02')                   1.18802            0.00281669
# Synset('hardware.n.03')                   0.0123511               0.15662
# Synset('computer.n.01')                   0.0132029              0.312061
# Synset('summons.n.03')                     0.249019            0.00312607
# Synset('particular.n.03')                  0.247891            0.00289918
# Synset('science.n.01')                            0            0.00351275
# Synset('design.n.06')                             0                     0
# Synset('sphere.n.01')                             0                     0
# Synset('scientist.n.01')                          0                     0
# Synset('engineering.n.03')                        0                     0
# Synset('terminus.n.03')                           0                     0
# Mean                                       0.306533             0.0329581
# Ratio_mean                                 0.389824             0.0419134
#
#                              Synset('sphere.n.01') Synset('scientist.n.01')  \
# Synset('information.n.05')               0.0523018               0.00330271
# Synset('understanding.n.01')             0.0525022               0.00358062
# Synset('trouble.n.01')                   0.0525351               0.00362645
# Synset('software.n.01')                  0.0526637               0.00380626
# Synset('discipline.n.02')                0.0520034                 0.002893
# Synset('hardware.n.03')                 0.00247484                 0.131628
# Synset('computer.n.01')                 0.00263674                 0.160153
# Synset('summons.n.03')                   0.0522962               0.00329492
# Synset('particular.n.03')                0.0520804               0.00299815
# Synset('science.n.01')                   0.0526791               0.00382787
# Synset('design.n.06')                   0.00223962                 0.159111
# Synset('sphere.n.01')                            0                0.0036123
# Synset('scientist.n.01')                         0                        0
# Synset('engineering.n.03')                       0                        0
# Synset('terminus.n.03')                          0                        0
# Mean                                     0.0284275                0.0321223
# Ratio_mean                               0.0361518                0.0408505
#
#                              Synset('engineering.n.03')  \
# Synset('information.n.05')                   0.00257306
# Synset('understanding.n.01')                 0.00273867
# Synset('trouble.n.01')                        0.0027654
# Synset('software.n.01')                      0.00286874
# Synset('discipline.n.02')                    0.00231738
# Synset('hardware.n.03')                        0.130462
# Synset('computer.n.01')                        0.259967
# Synset('summons.n.03')                       0.00256833
# Synset('particular.n.03')                    0.00238437
# Synset('science.n.01')                         0.002881
# Synset('design.n.06')                          0.259302
# Synset('sphere.n.01')                        0.00275716
# Synset('scientist.n.01')                       0.159029
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
# Mean                                          0.0555076
# Ratio_mean                                    0.0705901
#
#                              Synset('terminus.n.03')
# Synset('information.n.05')                 0.0392034
# Synset('understanding.n.01')               0.0393499
# Synset('trouble.n.01')                     0.0393739
# Synset('software.n.01')                    0.0394678
# Synset('discipline.n.02')                  0.0389847
# Synset('hardware.n.03')                    0.0785995
# Synset('computer.n.01')                     0.156485
# Synset('summons.n.03')                     0.0391993
# Synset('particular.n.03')                  0.0390412
# Synset('science.n.01')                      0.039479
# Synset('design.n.06')                       0.298106
# Synset('sphere.n.01')                       0.156695
# Synset('scientist.n.01')                   0.0959124
# Synset('engineering.n.03')                  0.155869
# Synset('terminus.n.03')                            0
# Mean                                       0.0837178
# Ratio_mean                                  0.106465

# %%
pragraph_freq_mean_pic=pragraph_freq_mean(p_IC_C_df,rmv_red_ratio)
pragraph_freq_mean_pic
# Out:
#                              Synset('information.n.05')  \
# Synset('information.n.05')                            0
# Synset('understanding.n.01')                          0
# Synset('trouble.n.01')                                0
# Synset('software.n.01')                               0
# Synset('discipline.n.02')                             0
# Synset('hardware.n.03')                               0
# Synset('computer.n.01')                               0
# Synset('summons.n.03')                                0
# Synset('particular.n.03')                             0
# Synset('science.n.01')                                0
# Synset('design.n.06')                                 0
# Synset('sphere.n.01')                                 0
# Synset('scientist.n.01')                              0
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
# Mean                                                  0
# Ratio_mean                                            0
#
#                              Synset('understanding.n.01')  \
# Synset('information.n.05')                        5.22827
# Synset('understanding.n.01')                            0
# Synset('trouble.n.01')                                  0
# Synset('software.n.01')                                 0
# Synset('discipline.n.02')                               0
# Synset('hardware.n.03')                                 0
# Synset('computer.n.01')                                 0
# Synset('summons.n.03')                                  0
# Synset('particular.n.03')                               0
# Synset('science.n.01')                                  0
# Synset('design.n.06')                                   0
# Synset('sphere.n.01')                                   0
# Synset('scientist.n.01')                                0
# Synset('engineering.n.03')                              0
# Synset('terminus.n.03')                                 0
# Mean                                             0.348551
# Ratio_mean                                     0.00443259
#
#                              Synset('trouble.n.01') Synset('software.n.01')  \
# Synset('information.n.05')                   6.5388                  6.5523
# Synset('understanding.n.01')                31.3689                 6.57983
# Synset('trouble.n.01')                            0                 6.58436
# Synset('software.n.01')                           0                       0
# Synset('discipline.n.02')                         0                       0
# Synset('hardware.n.03')                           0                       0
# Synset('computer.n.01')                           0                       0
# Synset('summons.n.03')                            0                       0
# Synset('particular.n.03')                         0                       0
# Synset('science.n.01')                            0                       0
# Synset('design.n.06')                             0                       0
# Synset('sphere.n.01')                             0                       0
# Synset('scientist.n.01')                          0                       0
# Synset('engineering.n.03')                        0                       0
# Synset('terminus.n.03')                           0                       0
# Mean                                        2.52718                 1.31443
# Ratio_mean                                0.0321387               0.0167159
#
#                              Synset('discipline.n.02')  \
# Synset('information.n.05')                     11.6674
# Synset('understanding.n.01')                   56.2258
# Synset('trouble.n.01')                         56.2348
# Synset('software.n.01')                         11.721
# Synset('discipline.n.02')                            0
# Synset('hardware.n.03')                              0
# Synset('computer.n.01')                              0
# Synset('summons.n.03')                               0
# Synset('particular.n.03')                            0
# Synset('science.n.01')                               0
# Synset('design.n.06')                                0
# Synset('sphere.n.01')                                0
# Synset('scientist.n.01')                             0
# Synset('engineering.n.03')                           0
# Synset('terminus.n.03')                              0
# Mean                                            9.0566
# Ratio_mean                                    0.115175
#
#                              Synset('hardware.n.03') Synset('computer.n.01')  \
# Synset('information.n.05')                  0.171819                 1.33594
# Synset('understanding.n.01')                0.184217                 1.43859
# Synset('trouble.n.01')                      0.186235                 1.45539
# Synset('software.n.01')                     0.194082                 1.52092
# Synset('discipline.n.02')                   0.153029                 1.18205
# Synset('hardware.n.03')                            0                 57.7211
# Synset('computer.n.01')                            0                       0
# Synset('summons.n.03')                             0                       0
# Synset('particular.n.03')                          0                       0
# Synset('science.n.01')                             0                       0
# Synset('design.n.06')                              0                       0
# Synset('sphere.n.01')                              0                       0
# Synset('scientist.n.01')                           0                       0
# Synset('engineering.n.03')                         0                       0
# Synset('terminus.n.03')                            0                       0
# Mean                                       0.0592921                 4.31026
# Ratio_mean                               0.000754029               0.0548144
#
#                              Synset('summons.n.03') Synset('particular.n.03')  \
# Synset('information.n.05')                  5.21075                   3.89413
# Synset('understanding.n.01')                5.22771                   3.90483
# Synset('trouble.n.01')                      5.23047                   3.90656
# Synset('software.n.01')                     34.0729                   17.5448
# Synset('discipline.n.02')                   5.18511                   3.87771
# Synset('hardware.n.03')                    0.228624                  0.157911
# Synset('computer.n.01')                    0.242372                  0.166615
# Synset('summons.n.03')                            0                   17.5115
# Synset('particular.n.03')                         0                         0
# Synset('science.n.01')                            0                         0
# Synset('design.n.06')                             0                         0
# Synset('sphere.n.01')                             0                         0
# Synset('scientist.n.01')                          0                         0
# Synset('engineering.n.03')                        0                         0
# Synset('terminus.n.03')                           0                         0
# Mean                                         3.6932                    3.3976
# Ratio_mean                                0.0469671                  0.043208
#
#                              Synset('science.n.01') Synset('design.n.06')  \
# Synset('information.n.05')                  24.9049              0.313191
# Synset('understanding.n.01')                119.355              0.333656
# Synset('trouble.n.01')                      119.395              0.336963
# Synset('software.n.01')                     25.0963              0.349756
# Synset('discipline.n.02')                   118.802              0.281669
# Synset('hardware.n.03')                     1.23511                15.662
# Synset('computer.n.01')                     1.32029               31.2061
# Synset('summons.n.03')                      24.9019              0.312607
# Synset('particular.n.03')                   24.7891              0.289918
# Synset('science.n.01')                            0              0.351275
# Synset('design.n.06')                             0                     0
# Synset('sphere.n.01')                             0                     0
# Synset('scientist.n.01')                          0                     0
# Synset('engineering.n.03')                        0                     0
# Synset('terminus.n.03')                           0                     0
# Mean                                        30.6533               3.29581
# Ratio_mean                                 0.389824             0.0419134
#
#                              Synset('sphere.n.01') Synset('scientist.n.01')  \
# Synset('information.n.05')                 5.23018                 0.330271
# Synset('understanding.n.01')               5.25022                 0.358062
# Synset('trouble.n.01')                     5.25351                 0.362645
# Synset('software.n.01')                    5.26637                 0.380626
# Synset('discipline.n.02')                  5.20034                   0.2893
# Synset('hardware.n.03')                   0.247484                  13.1628
# Synset('computer.n.01')                   0.263674                  16.0153
# Synset('summons.n.03')                     5.22962                 0.329492
# Synset('particular.n.03')                  5.20804                 0.299815
# Synset('science.n.01')                     5.26791                 0.382787
# Synset('design.n.06')                     0.223962                  15.9111
# Synset('sphere.n.01')                            0                  0.36123
# Synset('scientist.n.01')                         0                        0
# Synset('engineering.n.03')                       0                        0
# Synset('terminus.n.03')                          0                        0
# Mean                                       2.84275                  3.21223
# Ratio_mean                               0.0361518                0.0408505
#
#                              Synset('engineering.n.03')  \
# Synset('information.n.05')                     0.257306
# Synset('understanding.n.01')                   0.273867
# Synset('trouble.n.01')                          0.27654
# Synset('software.n.01')                        0.286874
# Synset('discipline.n.02')                      0.231738
# Synset('hardware.n.03')                         13.0462
# Synset('computer.n.01')                         25.9967
# Synset('summons.n.03')                         0.256833
# Synset('particular.n.03')                      0.238437
# Synset('science.n.01')                           0.2881
# Synset('design.n.06')                           25.9302
# Synset('sphere.n.01')                          0.275716
# Synset('scientist.n.01')                        15.9029
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
# Mean                                            5.55076
# Ratio_mean                                    0.0705901
#
#                              Synset('terminus.n.03')
# Synset('information.n.05')                   3.92034
# Synset('understanding.n.01')                 3.93499
# Synset('trouble.n.01')                       3.93739
# Synset('software.n.01')                      3.94678
# Synset('discipline.n.02')                    3.89847
# Synset('hardware.n.03')                      7.85995
# Synset('computer.n.01')                      15.6485
# Synset('summons.n.03')                       3.91993
# Synset('particular.n.03')                    3.90412
# Synset('science.n.01')                        3.9479
# Synset('design.n.06')                        29.8106
# Synset('sphere.n.01')                        15.6695
# Synset('scientist.n.01')                     9.59124
# Synset('engineering.n.03')                   15.5869
# Synset('terminus.n.03')                            0
# Mean                                         8.37178
# Ratio_mean                                  0.106465

# %%
mjcn_df=add_mean_ratio(jcn_df)
mjcn_df
# Out:
#                              Synset('information.n.05')  \
# Synset('information.n.05')                            0
# Synset('understanding.n.01')                          0
# Synset('trouble.n.01')                                0
# Synset('software.n.01')                               0
# Synset('discipline.n.02')                             0
# Synset('hardware.n.03')                               0
# Synset('computer.n.01')                               0
# Synset('summons.n.03')                                0
# Synset('particular.n.03')                             0
# Synset('science.n.01')                                0
# Synset('design.n.06')                                 0
# Synset('sphere.n.01')                                 0
# Synset('scientist.n.01')                              0
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
# Mean                                                  0
# Ratio_mean                                            0
#
#                              Synset('understanding.n.01')  \
# Synset('information.n.05')                      0.0623568
# Synset('understanding.n.01')                            0
# Synset('trouble.n.01')                                  0
# Synset('software.n.01')                                 0
# Synset('discipline.n.02')                               0
# Synset('hardware.n.03')                                 0
# Synset('computer.n.01')                                 0
# Synset('summons.n.03')                                  0
# Synset('particular.n.03')                               0
# Synset('science.n.01')                                  0
# Synset('design.n.06')                                   0
# Synset('sphere.n.01')                                   0
# Synset('scientist.n.01')                                0
# Synset('engineering.n.03')                              0
# Synset('terminus.n.03')                                 0
# Mean                                           0.00415712
# Ratio_mean                                     0.00891459
#
#                              Synset('trouble.n.01') Synset('software.n.01')  \
# Synset('information.n.05')                0.0630506               0.0657508
# Synset('understanding.n.01')               0.101266               0.0712561
# Synset('trouble.n.01')                            0               0.0721635
# Synset('software.n.01')                           0                       0
# Synset('discipline.n.02')                         0                       0
# Synset('hardware.n.03')                           0                       0
# Synset('computer.n.01')                           0                       0
# Synset('summons.n.03')                            0                       0
# Synset('particular.n.03')                         0                       0
# Synset('science.n.01')                            0                       0
# Synset('design.n.06')                             0                       0
# Synset('sphere.n.01')                             0                       0
# Synset('scientist.n.01')                          0                       0
# Synset('engineering.n.03')                        0                       0
# Synset('terminus.n.03')                           0                       0
# Mean                                      0.0109545               0.0139447
# Ratio_mean                                0.0234909               0.0299032
#
#                              Synset('discipline.n.02')  \
# Synset('information.n.05')                   0.0516642
# Synset('understanding.n.01')                 0.0747919
# Synset('trouble.n.01')                       0.0757923
# Synset('software.n.01')                      0.0576272
# Synset('discipline.n.02')                            0
# Synset('hardware.n.03')                              0
# Synset('computer.n.01')                              0
# Synset('summons.n.03')                               0
# Synset('particular.n.03')                            0
# Synset('science.n.01')                               0
# Synset('design.n.06')                                0
# Synset('sphere.n.01')                                0
# Synset('scientist.n.01')                             0
# Synset('engineering.n.03')                           0
# Synset('terminus.n.03')                              0
# Mean                                          0.017325
# Ratio_mean                                   0.0371521
#
#                              Synset('hardware.n.03') Synset('computer.n.01')  \
# Synset('information.n.05')                 0.0572731               0.0607247
# Synset('understanding.n.01')               0.0614056               0.0653906
# Synset('trouble.n.01')                     0.0620783                0.066154
# Synset('software.n.01')                    0.0646942               0.0691328
# Synset('discipline.n.02')                  0.0510095               0.0537295
# Synset('hardware.n.03')                            0               0.0774187
# Synset('computer.n.01')                            0                       0
# Synset('summons.n.03')                             0                       0
# Synset('particular.n.03')                          0                       0
# Synset('science.n.01')                             0                       0
# Synset('design.n.06')                              0                       0
# Synset('sphere.n.01')                              0                       0
# Synset('scientist.n.01')                           0                       0
# Synset('engineering.n.03')                         0                       0
# Synset('terminus.n.03')                            0                       0
# Mean                                        0.019764                 0.02617
# Ratio_mean                                 0.0423823               0.0561194
#
#                              Synset('summons.n.03') Synset('particular.n.03')  \
# Synset('information.n.05')                0.0579792                 0.0533344
# Synset('understanding.n.01')               0.062218                 0.0569003
# Synset('trouble.n.01')                    0.0629087                 0.0574775
# Synset('software.n.01')                    0.116376                 0.0795565
# Synset('discipline.n.02')                 0.0515688                 0.0478615
# Synset('hardware.n.03')                    0.057156                  0.052637
# Synset('computer.n.01')                    0.060593                 0.0555383
# Synset('summons.n.03')                            0                 0.0684541
# Synset('particular.n.03')                         0                         0
# Synset('science.n.01')                            0                         0
# Synset('design.n.06')                             0                         0
# Synset('sphere.n.01')                             0                         0
# Synset('scientist.n.01')                          0                         0
# Synset('engineering.n.03')                        0                         0
# Synset('terminus.n.03')                           0                         0
# Mean                                      0.0312533                 0.0314506
# Ratio_mean                                  0.06702                 0.0674432
#
#                              Synset('science.n.01') Synset('design.n.06')  \
# Synset('information.n.05')                0.0660729             0.0521985
# Synset('understanding.n.01')               0.109296             0.0556093
# Synset('trouble.n.01')                     0.111446             0.0561604
# Synset('software.n.01')                   0.0761502             0.0582927
# Synset('discipline.n.02')                 0.0802023             0.0469448
# Synset('hardware.n.03')                    0.065006             0.0640752
# Synset('computer.n.01')                    0.069489             0.0789185
# Synset('summons.n.03')                    0.0659171             0.0521011
# Synset('particular.n.03')                 0.0599785             0.0483197
# Synset('science.n.01')                            0             0.0585458
# Synset('design.n.06')                             0                     0
# Synset('sphere.n.01')                             0                     0
# Synset('scientist.n.01')                          0                     0
# Synset('engineering.n.03')                        0                     0
# Synset('terminus.n.03')                           0                     0
# Mean                                      0.0469039             0.0380777
# Ratio_mean                                 0.100581             0.0816545
#
#                              Synset('sphere.n.01') Synset('scientist.n.01')  \
# Synset('information.n.05')               0.0628367                0.0660541
# Synset('understanding.n.01')             0.0678461                0.0716124
# Synset('trouble.n.01')                   0.0686683                 0.072529
# Synset('software.n.01')                  0.0718834                0.0761252
# Synset('discipline.n.02')                0.0553763                  0.05786
# Synset('hardware.n.03')                  0.0618709                0.0862953
# Synset('computer.n.01')                  0.0659185                0.0990353
# Synset('summons.n.03')                   0.0626957                0.0658983
# Synset('particular.n.03')                0.0572996                 0.059963
# Synset('science.n.01')                   0.0722685                0.0765573
# Synset('design.n.06')                    0.0559906                0.0782026
# Synset('sphere.n.01')                            0                 0.072246
# Synset('scientist.n.01')                         0                        0
# Synset('engineering.n.03')                       0                        0
# Synset('terminus.n.03')                          0                        0
# Mean                                     0.0468436                0.0588252
# Ratio_mean                                0.100452                 0.126146
#
#                              Synset('engineering.n.03')  \
# Synset('information.n.05')                    0.0514613
# Synset('understanding.n.01')                  0.0547734
# Synset('trouble.n.01')                         0.055308
# Synset('software.n.01')                       0.0573749
# Synset('discipline.n.02')                     0.0463477
# Synset('hardware.n.03')                        0.062968
# Synset('computer.n.01')                       0.0772455
# Synset('summons.n.03')                        0.0513667
# Synset('particular.n.03')                     0.0476873
# Synset('science.n.01')                          0.05762
# Synset('design.n.06')                         0.0639565
# Synset('sphere.n.01')                         0.0551433
# Synset('scientist.n.01')                      0.0765595
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
# Mean                                          0.0505208
# Ratio_mean                                     0.108338
#
#                              Synset('terminus.n.03')
# Synset('information.n.05')                  0.062071
# Synset('understanding.n.01')               0.0669544
# Synset('trouble.n.01')                      0.067755
# Synset('software.n.01')                    0.0708832
# Synset('discipline.n.02')                  0.0547809
# Synset('hardware.n.03')                    0.0737168
# Synset('computer.n.01')                    0.0940726
# Synset('summons.n.03')                     0.0619335
# Synset('particular.n.03')                  0.0566623
# Synset('science.n.01')                     0.0712577
# Synset('design.n.06')                       0.114371
# Synset('sphere.n.01')                      0.0909789
# Synset('scientist.n.01')                   0.0930573
# Synset('engineering.n.03')                 0.0735597
# Synset('terminus.n.03')                            0
# Mean                                       0.0701369
# Ratio_mean                                  0.150403

# %%
picc=add_mean_ratio(p_IC_C_df)
picc
# Out:
#                              Synset('information.n.05')  \
# Synset('information.n.05')                            0
# Synset('understanding.n.01')                          0
# Synset('trouble.n.01')                                0
# Synset('software.n.01')                               0
# Synset('discipline.n.02')                             0
# Synset('hardware.n.03')                               0
# Synset('computer.n.01')                               0
# Synset('summons.n.03')                                0
# Synset('particular.n.03')                             0
# Synset('science.n.01')                                0
# Synset('design.n.06')                                 0
# Synset('sphere.n.01')                                 0
# Synset('scientist.n.01')                              0
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
# Mean                                                  0
# Ratio_mean                                            0
#
#                              Synset('understanding.n.01')  \
# Synset('information.n.05')                        1.30707
# Synset('understanding.n.01')                            0
# Synset('trouble.n.01')                                  0
# Synset('software.n.01')                                 0
# Synset('discipline.n.02')                               0
# Synset('hardware.n.03')                                 0
# Synset('computer.n.01')                                 0
# Synset('summons.n.03')                                  0
# Synset('particular.n.03')                               0
# Synset('science.n.01')                                  0
# Synset('design.n.06')                                   0
# Synset('sphere.n.01')                                   0
# Synset('scientist.n.01')                                0
# Synset('engineering.n.03')                              0
# Synset('terminus.n.03')                                 0
# Mean                                            0.0871378
# Ratio_mean                                     0.00754454
#
#                              Synset('trouble.n.01') Synset('software.n.01')  \
# Synset('information.n.05')                  1.30776                 1.31046
# Synset('understanding.n.01')                6.27379                 1.31597
# Synset('trouble.n.01')                            0                 1.31687
# Synset('software.n.01')                           0                       0
# Synset('discipline.n.02')                         0                       0
# Synset('hardware.n.03')                           0                       0
# Synset('computer.n.01')                           0                       0
# Synset('summons.n.03')                            0                       0
# Synset('particular.n.03')                         0                       0
# Synset('science.n.01')                            0                       0
# Synset('design.n.06')                             0                       0
# Synset('sphere.n.01')                             0                       0
# Synset('scientist.n.01')                          0                       0
# Synset('engineering.n.03')                        0                       0
# Synset('terminus.n.03')                           0                       0
# Mean                                       0.505437                0.262887
# Ratio_mean                                0.0437616               0.0227612
#
#                              Synset('discipline.n.02')  \
# Synset('information.n.05')                     1.29637
# Synset('understanding.n.01')                   6.24731
# Synset('trouble.n.01')                         6.24831
# Synset('software.n.01')                        1.30234
# Synset('discipline.n.02')                            0
# Synset('hardware.n.03')                              0
# Synset('computer.n.01')                              0
# Synset('summons.n.03')                               0
# Synset('particular.n.03')                            0
# Synset('science.n.01')                               0
# Synset('design.n.06')                                0
# Synset('sphere.n.01')                                0
# Synset('scientist.n.01')                             0
# Synset('engineering.n.03')                           0
# Synset('terminus.n.03')                              0
# Mean                                           1.00629
# Ratio_mean                                   0.0871263
#
#                              Synset('hardware.n.03') Synset('computer.n.01')  \
# Synset('information.n.05')                 0.0572731               0.0607247
# Synset('understanding.n.01')               0.0614056               0.0653906
# Synset('trouble.n.01')                     0.0620783                0.066154
# Synset('software.n.01')                    0.0646942               0.0691328
# Synset('discipline.n.02')                  0.0510095               0.0537295
# Synset('hardware.n.03')                            0                 2.62368
# Synset('computer.n.01')                            0                       0
# Synset('summons.n.03')                             0                       0
# Synset('particular.n.03')                          0                       0
# Synset('science.n.01')                             0                       0
# Synset('design.n.06')                              0                       0
# Synset('sphere.n.01')                              0                       0
# Synset('scientist.n.01')                           0                       0
# Synset('engineering.n.03')                         0                       0
# Synset('terminus.n.03')                            0                       0
# Mean                                        0.019764                0.195921
# Ratio_mean                                0.00171121               0.0169632
#
#                              Synset('summons.n.03') Synset('particular.n.03')  \
# Synset('information.n.05')                  1.30269                   1.29804
# Synset('understanding.n.01')                1.30693                   1.30161
# Synset('trouble.n.01')                      1.30762                   1.30219
# Synset('software.n.01')                     8.51823                   5.84827
# Synset('discipline.n.02')                   1.29628                   1.29257
# Synset('hardware.n.03')                    0.057156                  0.052637
# Synset('computer.n.01')                    0.060593                 0.0555383
# Synset('summons.n.03')                            0                   5.83716
# Synset('particular.n.03')                         0                         0
# Synset('science.n.01')                            0                         0
# Synset('design.n.06')                             0                         0
# Synset('sphere.n.01')                             0                         0
# Synset('scientist.n.01')                          0                         0
# Synset('engineering.n.03')                        0                         0
# Synset('terminus.n.03')                           0                         0
# Mean                                       0.923299                   1.13253
# Ratio_mean                                0.0799409                 0.0980568
#
#                              Synset('science.n.01') Synset('design.n.06')  \
# Synset('information.n.05')                  1.31078             0.0521985
# Synset('understanding.n.01')                6.28182             0.0556093
# Synset('trouble.n.01')                      6.28397             0.0561604
# Synset('software.n.01')                     1.32086             0.0582927
# Synset('discipline.n.02')                   6.25272             0.0469448
# Synset('hardware.n.03')                    0.065006               2.61034
# Synset('computer.n.01')                    0.069489               5.20101
# Synset('summons.n.03')                      1.31063             0.0521011
# Synset('particular.n.03')                   1.30469             0.0483197
# Synset('science.n.01')                            0             0.0585458
# Synset('design.n.06')                             0                     0
# Synset('sphere.n.01')                             0                     0
# Synset('scientist.n.01')                          0                     0
# Synset('engineering.n.03')                        0                     0
# Synset('terminus.n.03')                           0                     0
# Mean                                        1.61333              0.549301
# Ratio_mean                                 0.139685             0.0475595
#
#                              Synset('sphere.n.01') Synset('scientist.n.01')  \
# Synset('information.n.05')                 1.30755                0.0660541
# Synset('understanding.n.01')               1.31256                0.0716124
# Synset('trouble.n.01')                     1.31338                 0.072529
# Synset('software.n.01')                    1.31659                0.0761252
# Synset('discipline.n.02')                  1.30009                  0.05786
# Synset('hardware.n.03')                  0.0618709                  2.63256
# Synset('computer.n.01')                  0.0659185                  3.20306
# Synset('summons.n.03')                     1.30741                0.0658983
# Synset('particular.n.03')                  1.30201                 0.059963
# Synset('science.n.01')                     1.31698                0.0765573
# Synset('design.n.06')                    0.0559906                  3.18223
# Synset('sphere.n.01')                            0                 0.072246
# Synset('scientist.n.01')                         0                        0
# Synset('engineering.n.03')                       0                        0
# Synset('terminus.n.03')                          0                        0
# Mean                                      0.710689                 0.642446
# Ratio_mean                               0.0615327                0.0556241
#
#                              Synset('engineering.n.03')  \
# Synset('information.n.05')                    0.0514613
# Synset('understanding.n.01')                  0.0547734
# Synset('trouble.n.01')                         0.055308
# Synset('software.n.01')                       0.0573749
# Synset('discipline.n.02')                     0.0463477
# Synset('hardware.n.03')                         2.60923
# Synset('computer.n.01')                         5.19934
# Synset('summons.n.03')                        0.0513667
# Synset('particular.n.03')                     0.0476873
# Synset('science.n.01')                          0.05762
# Synset('design.n.06')                           5.18605
# Synset('sphere.n.01')                         0.0551433
# Synset('scientist.n.01')                        3.18058
# Synset('engineering.n.03')                            0
# Synset('terminus.n.03')                               0
# Mean                                            1.11015
# Ratio_mean                                    0.0961189
#
#                              Synset('terminus.n.03')
# Synset('information.n.05')                   1.30678
# Synset('understanding.n.01')                 1.31166
# Synset('trouble.n.01')                       1.31246
# Synset('software.n.01')                      1.31559
# Synset('discipline.n.02')                    1.29949
# Synset('hardware.n.03')                      2.61998
# Synset('computer.n.01')                      5.21616
# Synset('summons.n.03')                       1.30664
# Synset('particular.n.03')                    1.30137
# Synset('science.n.01')                       1.31597
# Synset('design.n.06')                        9.93686
# Synset('sphere.n.01')                        5.22317
# Synset('scientist.n.01')                     3.19708
# Synset('engineering.n.03')                   5.19565
# Synset('terminus.n.03')                            0
# Mean                                         2.79059
# Ratio_mean                                  0.241614

# %%
import numpy as np
lesk_vec=[]# synset lesk of words per pragraph
synset_lesk_noDuplicates=[]
Sentences=pragraph_to_setnences(pragraphs[1])
for sentence in Sentences:
    Words=remove_stopword_sentences(sentence)
    for word in Words:
        lesk_synset=lesk_word_sentence(word,sentence)
        if lesk_synset is not None:
            lesk_vec.append(lesk_synset)

#Count Freq
df_freq=count_freq(lesk_vec)
df_freq
#print(df_freq.values.sum())
#print(df_freq.T)

ss=DataFrame.dropna(df_freq[df_freq.ix['Freq':] > 1].T)
#total=ss.values.sum().sum()
#ss['Ratio']=(ss['Freq']/total)
#ss.T
ss.apply(np.mean)
#ss.ix[0,1 ] #[col,row] #.apply(np.mean)
# Out:
# Freq    3.25
# dtype: float64

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Pragraph Bar Chart

# %%
'''
return bar chart of pragraph 
'''

import seaborn as sns
def pragraph_bar_ratio_mean_sns(pragraph_df):
    df=pragraph_df.T[['Ratio_mean']].T
    return sns.factorplot(data=df, kind='bar')

# %%
#pragraph_bar_ratio_mean_sns(mjcn_df)

# %%
import matplotlib.pyplot as plt
'''
bar per column in dataframe
'''
def pragraph_bar_ratio_mean(pragraph_df):
    df=pragraph_df.T[['Ratio_mean']]
    ax = df.plot(kind='bar', title ="Key Word Ratio", figsize=(10, 10), legend=True, fontsize=12)
    ax.set_xlabel("Key Words", fontsize=12)
    ax.set_ylabel("Ratio_mean", fontsize=12)
    plt.show()
    fig = ax.get_figure()
    fig.savefig("total-sales.png")

# %%
#pragraph_bar_ratio_mean(mjcn_df)

# %% [markdown]
# ## Pragraph Pie

# %%
'''
return pie of pragraph
'''

import matplotlib.pyplot as plt
def pragraph_pie_ratio_mean(pragraph_df):
    #plt.pie(mjcn_df.T[['Ratio_mean']])
    #mjcn_df.T[['Ratio_mean']].plot(kind='pie',subplots=True)
    fig = plt.figure(figsize=(6,6), dpi=200)
    ax = plt.subplot(111)
    fig2 = ax.get_figure()
    fig.savefig("pie.png")
    return pragraph_df.T[['Ratio_mean']].plot(kind='pie', ax=ax, autopct='%1.1f%%', startangle=270, fontsize=12, subplots=True)
    #mjcn_df.T[['Ratio_mean']]

# %%
pragraph_pie_ratio_mean(mjcn_df)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe2dc091748>], dtype=object)

# %%
pragraph_pie_ratio_mean(pragraph_ratio_mean_jcn)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe2dc0a3470>], dtype=object)

# %%
pragraph_pie_ratio_mean(pragraph_freq_mean_jcn)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe2c7246a90>], dtype=object)

# %%
pragraph_pie_ratio_mean(mres_df)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe2c702ba90>], dtype=object)

# %%
pragraph_pie_ratio_mean(pragraph_ratio_mean_res)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe2c71a8b38>], dtype=object)

# %%
pragraph_pie_ratio_mean(pragraph_ratio_mean_res)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe2cd50ae10>], dtype=object)

# %%
pragraph_pie_ratio_mean(picc)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe2c31e3cf8>], dtype=object)

# %%
pragraph_pie_ratio_mean(pragraph_ratio_mean_pic)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe2c265aa20>], dtype=object)

# %%
pragraph_pie_ratio_mean(pragraph_freq_mean_pic)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe2c1a1f978>], dtype=object)

# %%
def pragraph_concat_bar_ratio_mean(mjcn_df,picc,mres_df):
    df=pd.concat([mjcn_df.T[['Ratio_mean']].T,picc.T[['Ratio_mean']].T, mres_df.T[['Ratio_mean']].T])
    df.index=['JCN','RES','PICC']
    #df
    #df=pragraph_df.T[['Ratio_mean']]
    ax = df.T.plot(kind='bar', title ="Key Word Ratio", figsize=(10, 10), legend=True, fontsize=12)
    ax.set_xlabel("Key Words", fontsize=12)
    #ax.set_ylabel("Ratio_mean", fontsize=12)
    plt.show()

# %%
'''
After multible frequancy ratio in mean per column
'''
pragraph_concat_bar_ratio_mean(mjcn_df,picc,mres_df)

# %%
'''
After multible frequancy ratio in each element dataframe
'''
pragraph_concat_bar_ratio_mean(pragraph_ratio_mean_jcn,pragraph_ratio_mean_pic,pragraph_ratio_mean_res)

# %%
'''
After multible frequancy freq. in each element dataframe
'''
pragraph_concat_bar_ratio_mean(pragraph_freq_mean_jcn,pragraph_freq_mean_pic,pragraph_freq_mean_res)
